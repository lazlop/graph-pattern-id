# %%
from rdflib import Graph, URIRef, Namespace
from rdflib.namespace import split_uri

def get_namespaces(graph):
    """Extract all unique namespaces from all URIRefs in the graph."""
    namespaces = set()
    node_to_ns = {}
    for s, p, o in graph:
        for node in (s, p, o):
            if isinstance(node, URIRef):
                try:
                    ns, _ = split_uri(str(node))
                    namespaces.add(ns)
                    node_to_ns[node] = ns
                except Exception:
                    node_to_ns[node] = None
    return namespaces, node_to_ns

def is_namespace_bound(graph, ns):
    """Check if the namespace is already bound to any prefix."""
    for prefix, namespace in graph.namespace_manager.namespaces():
        if str(namespace) == ns:
            return True
    return False

def bind_or_remove_with_warning(graph):
    """Bind all unique namespaces to prefixes; remove triples if binding fails, with warnings."""
    namespaces, node_to_ns = get_namespaces(graph)
    prefix_counter = 1
    for ns in sorted(namespaces):
        if is_namespace_bound(graph, ns):
            # Namespace already has a prefix, skip binding
            continue
        prefix = f'ns{prefix_counter}'
        try:
            graph.bind(prefix, Namespace(ns))
            prefix_counter += 1
        except Exception as e:
            # Remove all triples using this namespace and warn
            triples_to_remove = []
            for s, p, o in graph:
                for node in (s, p, o):
                    if isinstance(node, URIRef) and str(node).startswith(ns):
                        triples_to_remove.append((s, p, o))
                        break
            if triples_to_remove:
                print(f"WARNING: Could not bind namespace '{ns}'; removing {len(triples_to_remove)} triples:")
                for triple in triples_to_remove:
                    print("   ", triple)
                for triple in triples_to_remove:
                    graph.remove(triple)
    # Handle nodes with unextractable namespaces
    for node, ns in node_to_ns.items():
        if ns is None:
            triples_to_remove = []
            for s, p, o in graph:
                if node in (s, p, o):
                    triples_to_remove.append((s, p, o))
            if triples_to_remove:
                print(f"WARNING: Could not extract namespace for node '{node}'; removing {len(triples_to_remove)} triples:")
                for triple in triples_to_remove:
                    print("   ", triple)
                for triple in triples_to_remove:
                    graph.remove(triple)

# %%
g = Graph()
g.parse('brick-example.ttl')
# g.parse('ontologies/Brick14.ttl')
# Out:
# <Graph identifier=Naaebb14beb78490ab5037186f8ad59d6 (<class 'rdflib.graph.Graph'>)>

# %%
bind_or_remove_with_warning(g)
# Out:
# WARNING: Could not extract namespace for node 'urn:example#'; removing 1 triples:
#     (rdflib.term.URIRef('urn:example#'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Ontology'))

# %%
g.skolemize()
# Out:
# <Graph identifier=N29ad7087e50643f4becf15bd11802c4f (<class 'rdflib.graph.Graph'>)>

# %%
print(g.serialize(format = 'ttl'))
# Out:
# @prefix : <urn:example#> .
# @prefix brick: <https://brickschema.org/schema/Brick#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# :multiple-zone-ahu_name_0 a brick:AHU ;
#     rdfs:label "AHU" ;
#     brick:feeds :vav-cooling-only_name_0_0,
#         :vav-cooling-only_name_0_1,
#         :vav-cooling-only_name_0_10,
#         :vav-cooling-only_name_0_11,
#         :vav-cooling-only_name_0_12,
#         :vav-cooling-only_name_0_13,
#         :vav-cooling-only_name_0_14,
#         :vav-cooling-only_name_0_2,
#         :vav-cooling-only_name_0_3,
#         :vav-cooling-only_name_0_4,
#         :vav-cooling-only_name_0_5,
#         :vav-cooling-only_name_0_6,
#         :vav-cooling-only_name_0_7,
#         :vav-cooling-only_name_0_8,
#         :vav-cooling-only_name_0_9,
#         :vav-with-reheat_name_0_0,
#         :vav-with-reheat_name_0_1,
#         :vav-with-reheat_name_0_10,
#         :vav-with-reheat_name_0_11,
#         :vav-with-reheat_name_0_12,
#         :vav-with-reheat_name_0_13,
#         :vav-with-reheat_name_0_14,
#         :vav-with-reheat_name_0_2,
#         :vav-with-reheat_name_0_3,
#         :vav-with-reheat_name_0_4,
#         :vav-with-reheat_name_0_5,
#         :vav-with-reheat_name_0_6,
#         :vav-with-reheat_name_0_7,
#         :vav-with-reheat_name_0_8,
#         :vav-with-reheat_name_0_9 ;
#     brick:hasPart :multiple-zone-ahu_clg_coil_0,
#         :multiple-zone-ahu_htg_coil_0,
#         :multiple-zone-ahu_ra_damper_0,
#         :multiple-zone-ahu_sa_fan_0 ;
#     brick:hasPoint :multiple-zone-ahu_filter_pd_0,
#         :multiple-zone-ahu_ma_temp_0,
#         :multiple-zone-ahu_oa_temp_0,
#         :multiple-zone-ahu_ra_temp_0,
#         :multiple-zone-ahu_sa_temp_0 .
#
# :multiple-zone-ahu_name_1 a brick:AHU ;
#     rdfs:label "AHU" ;
#     brick:feeds :vav-cooling-only_name_1_0,
#         :vav-cooling-only_name_1_1,
#         :vav-cooling-only_name_1_10,
#         :vav-cooling-only_name_1_11,
#         :vav-cooling-only_name_1_12,
#         :vav-cooling-only_name_1_13,
#         :vav-cooling-only_name_1_14,
#         :vav-cooling-only_name_1_2,
#         :vav-cooling-only_name_1_3,
#         :vav-cooling-only_name_1_4,
#         :vav-cooling-only_name_1_5,
#         :vav-cooling-only_name_1_6,
#         :vav-cooling-only_name_1_7,
#         :vav-cooling-only_name_1_8,
#         :vav-cooling-only_name_1_9,
#         :vav-with-reheat_name_1_0,
#         :vav-with-reheat_name_1_1,
#         :vav-with-reheat_name_1_10,
#         :vav-with-reheat_name_1_11,
#         :vav-with-reheat_name_1_12,
#         :vav-with-reheat_name_1_13,
#         :vav-with-reheat_name_1_14,
#         :vav-with-reheat_name_1_2,
#         :vav-with-reheat_name_1_3,
#         :vav-with-reheat_name_1_4,
#         :vav-with-reheat_name_1_5,
#         :vav-with-reheat_name_1_6,
#         :vav-with-reheat_name_1_7,
#         :vav-with-reheat_name_1_8,
#         :vav-with-reheat_name_1_9 ;
#     brick:hasPart :multiple-zone-ahu_clg_coil_1,
#         :multiple-zone-ahu_htg_coil_1,
#         :multiple-zone-ahu_ra_damper_1,
#         :multiple-zone-ahu_sa_fan_1 ;
#     brick:hasPoint :multiple-zone-ahu_filter_pd_1,
#         :multiple-zone-ahu_ma_temp_1,
#         :multiple-zone-ahu_oa_temp_1,
#         :multiple-zone-ahu_ra_temp_1,
#         :multiple-zone-ahu_sa_temp_1 .
#
# :multiple-zone-ahu_name_2 a brick:AHU ;
#     rdfs:label "AHU" ;
#     brick:feeds :vav-cooling-only_name_2_0,
#         :vav-cooling-only_name_2_1,
#         :vav-cooling-only_name_2_10,
#         :vav-cooling-only_name_2_11,
#         :vav-cooling-only_name_2_12,
#         :vav-cooling-only_name_2_13,
#         :vav-cooling-only_name_2_14,
#         :vav-cooling-only_name_2_2,
#         :vav-cooling-only_name_2_3,
#         :vav-cooling-only_name_2_4,
#         :vav-cooling-only_name_2_5,
#         :vav-cooling-only_name_2_6,
#         :vav-cooling-only_name_2_7,
#         :vav-cooling-only_name_2_8,
#         :vav-cooling-only_name_2_9,
#         :vav-with-reheat_name_2_0,
#         :vav-with-reheat_name_2_1,
#         :vav-with-reheat_name_2_10,
#         :vav-with-reheat_name_2_11,
#         :vav-with-reheat_name_2_12,
#         :vav-with-reheat_name_2_13,
#         :vav-with-reheat_name_2_14,
#         :vav-with-reheat_name_2_2,
#         :vav-with-reheat_name_2_3,
#         :vav-with-reheat_name_2_4,
#         :vav-with-reheat_name_2_5,
#         :vav-with-reheat_name_2_6,
#         :vav-with-reheat_name_2_7,
#         :vav-with-reheat_name_2_8,
#         :vav-with-reheat_name_2_9 ;
#     brick:hasPart :multiple-zone-ahu_clg_coil_2,
#         :multiple-zone-ahu_htg_coil_2,
#         :multiple-zone-ahu_ra_damper_2,
#         :multiple-zone-ahu_sa_fan_2 ;
#     brick:hasPoint :multiple-zone-ahu_filter_pd_2,
#         :multiple-zone-ahu_ma_temp_2,
#         :multiple-zone-ahu_oa_temp_2,
#         :multiple-zone-ahu_ra_temp_2,
#         :multiple-zone-ahu_sa_temp_2 .
#
# :multiple-zone-ahu_name_3 a brick:AHU ;
#     rdfs:label "AHU" ;
#     brick:feeds :vav-cooling-only_name_3_0,
#         :vav-cooling-only_name_3_1,
#         :vav-cooling-only_name_3_10,
#         :vav-cooling-only_name_3_11,
#         :vav-cooling-only_name_3_12,
#         :vav-cooling-only_name_3_13,
#         :vav-cooling-only_name_3_14,
#         :vav-cooling-only_name_3_2,
#         :vav-cooling-only_name_3_3,
#         :vav-cooling-only_name_3_4,
#         :vav-cooling-only_name_3_5,
#         :vav-cooling-only_name_3_6,
#         :vav-cooling-only_name_3_7,
#         :vav-cooling-only_name_3_8,
#         :vav-cooling-only_name_3_9,
#         :vav-with-reheat_name_3_0,
#         :vav-with-reheat_name_3_1,
#         :vav-with-reheat_name_3_10,
#         :vav-with-reheat_name_3_11,
#         :vav-with-reheat_name_3_12,
#         :vav-with-reheat_name_3_13,
#         :vav-with-reheat_name_3_14,
#         :vav-with-reheat_name_3_2,
#         :vav-with-reheat_name_3_3,
#         :vav-with-reheat_name_3_4,
#         :vav-with-reheat_name_3_5,
#         :vav-with-reheat_name_3_6,
#         :vav-with-reheat_name_3_7,
#         :vav-with-reheat_name_3_8,
#         :vav-with-reheat_name_3_9 ;
#     brick:hasPart :multiple-zone-ahu_clg_coil_3,
#         :multiple-zone-ahu_htg_coil_3,
#         :multiple-zone-ahu_ra_damper_3,
#         :multiple-zone-ahu_sa_fan_3 ;
#     brick:hasPoint :multiple-zone-ahu_filter_pd_3,
#         :multiple-zone-ahu_ma_temp_3,
#         :multiple-zone-ahu_oa_temp_3,
#         :multiple-zone-ahu_ra_temp_3,
#         :multiple-zone-ahu_sa_temp_3 .
#
# :multiple-zone-ahu_clg_coil-valve_cmd_0 a brick:Valve_Position_Command ;
#     rdfs:label "Valve_Position_Command" .
#
# :multiple-zone-ahu_clg_coil-valve_cmd_1 a brick:Valve_Position_Command ;
#     rdfs:label "Valve_Position_Command" .
#
# :multiple-zone-ahu_clg_coil-valve_cmd_2 a brick:Valve_Position_Command ;
#     rdfs:label "Valve_Position_Command" .
#
# :multiple-zone-ahu_clg_coil-valve_cmd_3 a brick:Valve_Position_Command ;
#     rdfs:label "Valve_Position_Command" .
#
# :multiple-zone-ahu_clg_coil_0 a brick:Cooling_Coil ;
#     rdfs:label "Cooling_Coil" ;
#     brick:hasPoint :multiple-zone-ahu_clg_coil-valve_cmd_0 .
#
# :multiple-zone-ahu_clg_coil_1 a brick:Cooling_Coil ;
#     rdfs:label "Cooling_Coil" ;
#     brick:hasPoint :multiple-zone-ahu_clg_coil-valve_cmd_1 .
#
# :multiple-zone-ahu_clg_coil_2 a brick:Cooling_Coil ;
#     rdfs:label "Cooling_Coil" ;
#     brick:hasPoint :multiple-zone-ahu_clg_coil-valve_cmd_2 .
#
# :multiple-zone-ahu_clg_coil_3 a brick:Cooling_Coil ;
#     rdfs:label "Cooling_Coil" ;
#     brick:hasPoint :multiple-zone-ahu_clg_coil-valve_cmd_3 .
#
# :multiple-zone-ahu_filter_pd_0 a brick:Filter_Differential_Pressure_Sensor ;
#     rdfs:label "Filter_Differential_Pressure_Sensor" .
#
# :multiple-zone-ahu_filter_pd_1 a brick:Filter_Differential_Pressure_Sensor ;
#     rdfs:label "Filter_Differential_Pressure_Sensor" .
#
# :multiple-zone-ahu_filter_pd_2 a brick:Filter_Differential_Pressure_Sensor ;
#     rdfs:label "Filter_Differential_Pressure_Sensor" .
#
# :multiple-zone-ahu_filter_pd_3 a brick:Filter_Differential_Pressure_Sensor ;
#     rdfs:label "Filter_Differential_Pressure_Sensor" .
#
# :multiple-zone-ahu_htg_coil-valve_cmd_0 a brick:Valve_Position_Command ;
#     rdfs:label "Valve_Position_Command" .
#
# :multiple-zone-ahu_htg_coil-valve_cmd_1 a brick:Valve_Position_Command ;
#     rdfs:label "Valve_Position_Command" .
#
# :multiple-zone-ahu_htg_coil-valve_cmd_2 a brick:Valve_Position_Command ;
#     rdfs:label "Valve_Position_Command" .
#
# :multiple-zone-ahu_htg_coil-valve_cmd_3 a brick:Valve_Position_Command ;
#     rdfs:label "Valve_Position_Command" .
#
# :multiple-zone-ahu_htg_coil_0 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :multiple-zone-ahu_htg_coil-valve_cmd_0 .
#
# :multiple-zone-ahu_htg_coil_1 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :multiple-zone-ahu_htg_coil-valve_cmd_1 .
#
# :multiple-zone-ahu_htg_coil_2 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :multiple-zone-ahu_htg_coil-valve_cmd_2 .
#
# :multiple-zone-ahu_htg_coil_3 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :multiple-zone-ahu_htg_coil-valve_cmd_3 .
#
# :multiple-zone-ahu_ma_temp_0 a brick:Mixed_Air_Temperature_Sensor ;
#     rdfs:label "Mixed_Air_Temperature_Sensor" .
#
# :multiple-zone-ahu_ma_temp_1 a brick:Mixed_Air_Temperature_Sensor ;
#     rdfs:label "Mixed_Air_Temperature_Sensor" .
#
# :multiple-zone-ahu_ma_temp_2 a brick:Mixed_Air_Temperature_Sensor ;
#     rdfs:label "Mixed_Air_Temperature_Sensor" .
#
# :multiple-zone-ahu_ma_temp_3 a brick:Mixed_Air_Temperature_Sensor ;
#     rdfs:label "Mixed_Air_Temperature_Sensor" .
#
# :multiple-zone-ahu_oa_temp_0 a brick:Outside_Air_Temperature_Sensor ;
#     rdfs:label "Outside_Air_Temperature_Sensor" .
#
# :multiple-zone-ahu_oa_temp_1 a brick:Outside_Air_Temperature_Sensor ;
#     rdfs:label "Outside_Air_Temperature_Sensor" .
#
# :multiple-zone-ahu_oa_temp_2 a brick:Outside_Air_Temperature_Sensor ;
#     rdfs:label "Outside_Air_Temperature_Sensor" .
#
# :multiple-zone-ahu_oa_temp_3 a brick:Outside_Air_Temperature_Sensor ;
#     rdfs:label "Outside_Air_Temperature_Sensor" .
#
# :multiple-zone-ahu_ra_damper-dmppos_0 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :multiple-zone-ahu_ra_damper-dmppos_1 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :multiple-zone-ahu_ra_damper-dmppos_2 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :multiple-zone-ahu_ra_damper-dmppos_3 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :multiple-zone-ahu_ra_damper_0 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :multiple-zone-ahu_ra_damper-dmppos_0 .
#
# :multiple-zone-ahu_ra_damper_1 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :multiple-zone-ahu_ra_damper-dmppos_1 .
#
# :multiple-zone-ahu_ra_damper_2 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :multiple-zone-ahu_ra_damper-dmppos_2 .
#
# :multiple-zone-ahu_ra_damper_3 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :multiple-zone-ahu_ra_damper-dmppos_3 .
#
# :multiple-zone-ahu_ra_temp_0 a brick:Return_Air_Temperature_Sensor ;
#     rdfs:label "Return_Air_Temperature_Sensor" .
#
# :multiple-zone-ahu_ra_temp_1 a brick:Return_Air_Temperature_Sensor ;
#     rdfs:label "Return_Air_Temperature_Sensor" .
#
# :multiple-zone-ahu_ra_temp_2 a brick:Return_Air_Temperature_Sensor ;
#     rdfs:label "Return_Air_Temperature_Sensor" .
#
# :multiple-zone-ahu_ra_temp_3 a brick:Return_Air_Temperature_Sensor ;
#     rdfs:label "Return_Air_Temperature_Sensor" .
#
# :multiple-zone-ahu_sa_fan-speed_0 a brick:Frequency_Command ;
#     rdfs:label "Frequency_Command" .
#
# :multiple-zone-ahu_sa_fan-speed_1 a brick:Frequency_Command ;
#     rdfs:label "Frequency_Command" .
#
# :multiple-zone-ahu_sa_fan-speed_2 a brick:Frequency_Command ;
#     rdfs:label "Frequency_Command" .
#
# :multiple-zone-ahu_sa_fan-speed_3 a brick:Frequency_Command ;
#     rdfs:label "Frequency_Command" .
#
# :multiple-zone-ahu_sa_fan-start_stop_0 a brick:Start_Stop_Command ;
#     rdfs:label "Start_Stop_Command" .
#
# :multiple-zone-ahu_sa_fan-start_stop_1 a brick:Start_Stop_Command ;
#     rdfs:label "Start_Stop_Command" .
#
# :multiple-zone-ahu_sa_fan-start_stop_2 a brick:Start_Stop_Command ;
#     rdfs:label "Start_Stop_Command" .
#
# :multiple-zone-ahu_sa_fan-start_stop_3 a brick:Start_Stop_Command ;
#     rdfs:label "Start_Stop_Command" .
#
# :multiple-zone-ahu_sa_fan-status_0 a brick:Fan_Status ;
#     rdfs:label "Fan_Status" .
#
# :multiple-zone-ahu_sa_fan-status_1 a brick:Fan_Status ;
#     rdfs:label "Fan_Status" .
#
# :multiple-zone-ahu_sa_fan-status_2 a brick:Fan_Status ;
#     rdfs:label "Fan_Status" .
#
# :multiple-zone-ahu_sa_fan-status_3 a brick:Fan_Status ;
#     rdfs:label "Fan_Status" .
#
# :multiple-zone-ahu_sa_fan_0 a brick:Supply_Fan ;
#     rdfs:label "Supply_Fan" ;
#     brick:hasPoint :multiple-zone-ahu_sa_fan-speed_0,
#         :multiple-zone-ahu_sa_fan-start_stop_0,
#         :multiple-zone-ahu_sa_fan-status_0 .
#
# :multiple-zone-ahu_sa_fan_1 a brick:Supply_Fan ;
#     rdfs:label "Supply_Fan" ;
#     brick:hasPoint :multiple-zone-ahu_sa_fan-speed_1,
#         :multiple-zone-ahu_sa_fan-start_stop_1,
#         :multiple-zone-ahu_sa_fan-status_1 .
#
# :multiple-zone-ahu_sa_fan_2 a brick:Supply_Fan ;
#     rdfs:label "Supply_Fan" ;
#     brick:hasPoint :multiple-zone-ahu_sa_fan-speed_2,
#         :multiple-zone-ahu_sa_fan-start_stop_2,
#         :multiple-zone-ahu_sa_fan-status_2 .
#
# :multiple-zone-ahu_sa_fan_3 a brick:Supply_Fan ;
#     rdfs:label "Supply_Fan" ;
#     brick:hasPoint :multiple-zone-ahu_sa_fan-speed_3,
#         :multiple-zone-ahu_sa_fan-start_stop_3,
#         :multiple-zone-ahu_sa_fan-status_3 .
#
# :multiple-zone-ahu_sa_temp_0 a brick:Supply_Air_Temperature_Sensor ;
#     rdfs:label "Supply_Air_Temperature_Sensor" .
#
# :multiple-zone-ahu_sa_temp_1 a brick:Supply_Air_Temperature_Sensor ;
#     rdfs:label "Supply_Air_Temperature_Sensor" .
#
# :multiple-zone-ahu_sa_temp_2 a brick:Supply_Air_Temperature_Sensor ;
#     rdfs:label "Supply_Air_Temperature_Sensor" .
#
# :multiple-zone-ahu_sa_temp_3 a brick:Supply_Air_Temperature_Sensor ;
#     rdfs:label "Supply_Air_Temperature_Sensor" .
#
# :vav-cooling-only_co2_0_0 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_0_1 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_0_10 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_0_11 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_0_12 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_0_13 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_0_14 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_0_2 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_0_3 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_0_4 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_0_5 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_0_6 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_0_7 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_0_8 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_0_9 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_1_0 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_1_1 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_1_10 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_1_11 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_1_12 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_1_13 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_1_14 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_1_2 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_1_3 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_1_4 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_1_5 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_1_6 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_1_7 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_1_8 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_1_9 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_2_0 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_2_1 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_2_10 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_2_11 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_2_12 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_2_13 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_2_14 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_2_2 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_2_3 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_2_4 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_2_5 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_2_6 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_2_7 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_2_8 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_2_9 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_3_0 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_3_1 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_3_10 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_3_11 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_3_12 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_3_13 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_3_14 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_3_2 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_3_3 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_3_4 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_3_5 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_3_6 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_3_7 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_3_8 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_co2_3_9 a brick:CO2_Level_Sensor ;
#     rdfs:label "CO2_Level_Sensor" .
#
# :vav-cooling-only_dat_0_0 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_0_1 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_0_10 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_0_11 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_0_12 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_0_13 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_0_14 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_0_2 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_0_3 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_0_4 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_0_5 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_0_6 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_0_7 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_0_8 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_0_9 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_1_0 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_1_1 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_1_10 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_1_11 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_1_12 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_1_13 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_1_14 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_1_2 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_1_3 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_1_4 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_1_5 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_1_6 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_1_7 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_1_8 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_1_9 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_2_0 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_2_1 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_2_10 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_2_11 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_2_12 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_2_13 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_2_14 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_2_2 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_2_3 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_2_4 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_2_5 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_2_6 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_2_7 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_2_8 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_2_9 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_3_0 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_3_1 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_3_10 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_3_11 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_3_12 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_3_13 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_3_14 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_3_2 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_3_3 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_3_4 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_3_5 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_3_6 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_3_7 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_3_8 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dat_3_9 a brick:Discharge_Air_Temperature_Sensor ;
#     rdfs:label "Discharge_Air_Temperature_Sensor" .
#
# :vav-cooling-only_dmp-dmppos_0_0 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_0_1 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_0_10 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_0_11 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_0_12 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_0_13 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_0_14 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_0_2 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_0_3 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_0_4 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_0_5 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_0_6 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_0_7 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_0_8 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_0_9 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_1_0 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_1_1 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_1_10 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_1_11 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_1_12 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_1_13 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_1_14 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_1_2 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_1_3 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_1_4 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_1_5 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_1_6 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_1_7 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_1_8 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_1_9 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_2_0 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_2_1 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_2_10 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_2_11 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_2_12 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_2_13 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_2_14 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_2_2 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_2_3 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_2_4 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_2_5 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_2_6 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_2_7 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_2_8 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_2_9 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_3_0 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_3_1 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_3_10 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_3_11 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_3_12 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_3_13 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_3_14 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_3_2 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_3_3 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_3_4 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_3_5 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_3_6 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_3_7 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_3_8 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp-dmppos_3_9 a brick:Damper_Position_Command ;
#     rdfs:label "Damper_Position_Command" .
#
# :vav-cooling-only_dmp_0_0 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_0_0 .
#
# :vav-cooling-only_dmp_0_1 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_0_1 .
#
# :vav-cooling-only_dmp_0_10 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_0_10 .
#
# :vav-cooling-only_dmp_0_11 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_0_11 .
#
# :vav-cooling-only_dmp_0_12 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_0_12 .
#
# :vav-cooling-only_dmp_0_13 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_0_13 .
#
# :vav-cooling-only_dmp_0_14 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_0_14 .
#
# :vav-cooling-only_dmp_0_2 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_0_2 .
#
# :vav-cooling-only_dmp_0_3 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_0_3 .
#
# :vav-cooling-only_dmp_0_4 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_0_4 .
#
# :vav-cooling-only_dmp_0_5 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_0_5 .
#
# :vav-cooling-only_dmp_0_6 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_0_6 .
#
# :vav-cooling-only_dmp_0_7 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_0_7 .
#
# :vav-cooling-only_dmp_0_8 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_0_8 .
#
# :vav-cooling-only_dmp_0_9 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_0_9 .
#
# :vav-cooling-only_dmp_1_0 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_1_0 .
#
# :vav-cooling-only_dmp_1_1 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_1_1 .
#
# :vav-cooling-only_dmp_1_10 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_1_10 .
#
# :vav-cooling-only_dmp_1_11 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_1_11 .
#
# :vav-cooling-only_dmp_1_12 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_1_12 .
#
# :vav-cooling-only_dmp_1_13 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_1_13 .
#
# :vav-cooling-only_dmp_1_14 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_1_14 .
#
# :vav-cooling-only_dmp_1_2 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_1_2 .
#
# :vav-cooling-only_dmp_1_3 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_1_3 .
#
# :vav-cooling-only_dmp_1_4 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_1_4 .
#
# :vav-cooling-only_dmp_1_5 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_1_5 .
#
# :vav-cooling-only_dmp_1_6 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_1_6 .
#
# :vav-cooling-only_dmp_1_7 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_1_7 .
#
# :vav-cooling-only_dmp_1_8 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_1_8 .
#
# :vav-cooling-only_dmp_1_9 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_1_9 .
#
# :vav-cooling-only_dmp_2_0 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_2_0 .
#
# :vav-cooling-only_dmp_2_1 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_2_1 .
#
# :vav-cooling-only_dmp_2_10 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_2_10 .
#
# :vav-cooling-only_dmp_2_11 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_2_11 .
#
# :vav-cooling-only_dmp_2_12 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_2_12 .
#
# :vav-cooling-only_dmp_2_13 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_2_13 .
#
# :vav-cooling-only_dmp_2_14 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_2_14 .
#
# :vav-cooling-only_dmp_2_2 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_2_2 .
#
# :vav-cooling-only_dmp_2_3 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_2_3 .
#
# :vav-cooling-only_dmp_2_4 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_2_4 .
#
# :vav-cooling-only_dmp_2_5 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_2_5 .
#
# :vav-cooling-only_dmp_2_6 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_2_6 .
#
# :vav-cooling-only_dmp_2_7 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_2_7 .
#
# :vav-cooling-only_dmp_2_8 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_2_8 .
#
# :vav-cooling-only_dmp_2_9 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_2_9 .
#
# :vav-cooling-only_dmp_3_0 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_3_0 .
#
# :vav-cooling-only_dmp_3_1 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_3_1 .
#
# :vav-cooling-only_dmp_3_10 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_3_10 .
#
# :vav-cooling-only_dmp_3_11 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_3_11 .
#
# :vav-cooling-only_dmp_3_12 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_3_12 .
#
# :vav-cooling-only_dmp_3_13 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_3_13 .
#
# :vav-cooling-only_dmp_3_14 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_3_14 .
#
# :vav-cooling-only_dmp_3_2 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_3_2 .
#
# :vav-cooling-only_dmp_3_3 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_3_3 .
#
# :vav-cooling-only_dmp_3_4 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_3_4 .
#
# :vav-cooling-only_dmp_3_5 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_3_5 .
#
# :vav-cooling-only_dmp_3_6 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_3_6 .
#
# :vav-cooling-only_dmp_3_7 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_3_7 .
#
# :vav-cooling-only_dmp_3_8 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_3_8 .
#
# :vav-cooling-only_dmp_3_9 a brick:Damper ;
#     rdfs:label "Damper" ;
#     brick:hasPoint :vav-cooling-only_dmp-dmppos_3_9 .
#
# :vav-cooling-only_name_0_0 a brick:VAV ;
#     rdfs:label "VAV" ;
#     brick:feeds :vav-cooling-only_zone_0_0 ;
#     brick:hasPart :vav-cooling-only_dmp_0_0 ;
#     brick:hasPoint :vav-cooling-only_co2_0_0,
#         :vav-cooling-only_dat_0_0,
#         :vav-cooling-only_occ_0_0,
#         :vav-cooling-only_ztemp_0_0 .
#
# :vav-cooling-only_name_0_1 a brick:VAV ;
#     rdfs:label "VAV" ;
#     brick:feeds :vav-cooling-only_zone_0_1 ;
#     brick:hasPart :vav-cooling-only_dmp_0_1 ;
#     brick:hasPoint :vav-cooling-only_co2_0_1,
#         :vav-cooling-only_dat_0_1,
#         :vav-cooling-only_occ_0_1,
#         :vav-cooling-only_ztemp_0_1 .
#
# :vav-cooling-only_name_0_10 a brick:VAV ;
#     rdfs:label "VAV" ;
#     brick:feeds :vav-cooling-only_zone_0_10 ;
#     brick:hasPart :vav-cooling-only_dmp_0_10 ;
#     brick:hasPoint :vav-cooling-only_co2_0_10,
#         :vav-cooling-only_dat_0_10,
#         :vav-cooling-only_occ_0_10,
#         :vav-cooling-only_ztemp_0_10 .
#
# :vav-cooling-only_name_0_11 a brick:VAV ;
#     rdfs:label "VAV" ;
#     brick:feeds :vav-cooling-only_zone_0_11 ;
#     brick:hasPart :vav-cooling-only_dmp_0_11 ;
#     brick:hasPoint :vav-cooling-only_co2_0_11,
#         :vav-cooling-only_dat_0_11,
#         :vav-cooling-only_occ_0_11,
#         :vav-cooling-only_ztemp_0_11 .
#
# :vav-cooling-only_name_0_12 a brick:VAV ;
#     rdfs:label "VAV" ;
#     brick:feeds :vav-cooling-only_zone_0_12 ;
#     brick:hasPart :vav-cooling-only_dmp_0_12 ;
#     brick:hasPoint :vav-cooling-only_co2_0_12,
#         :vav-cooling-only_dat_0_12,
#         :vav-cooling-only_occ_0_12,
#         :vav-cooling-only_ztemp_0_12 .
#
# :vav-cooling-only_name_0_13 a brick:VAV ;
#     rdfs:label "VAV" ;
#     brick:feeds :vav-cooling-only_zone_0_13 ;
#     brick:hasPart :vav-cooling-only_dmp_0_13 ;
#     brick:hasPoint :vav-cooling-only_co2_0_13,
#         :vav-cooling-only_dat_0_13,
#         :vav-cooling-only_occ_0_13,
#         :vav-cooling-only_ztemp_0_13 .
#
# :vav-cooling-only_name_0_14 a brick:VAV ;
#     rdfs:label "VAV" ;
#     brick:feeds :vav-cooling-only_zone_0_14 ;
#     brick:hasPart :vav-cooling-only_dmp_0_14 ;
#     brick:hasPoint :vav-cooling-only_co2_0_14,
#         :vav-cooling-only_dat_0_14,
#         :vav-cooling-only_occ_0_14,
#         :vav-cooling-only_ztemp_0_14 .
#
# :vav-cooling-only_name_0_2 a brick:VAV ;
#     rdfs:label "VAV" ;
#     brick:feeds :vav-cooling-only_zone_0_2 ;
#     brick:hasPart :vav-cooling-only_dmp_0_2 ;
#     brick:hasPoint :vav-cooling-only_co2_0_2,
#         :vav-cooling-only_dat_0_2,
#         :vav-cooling-only_occ_0_2,
#         :vav-cooling-only_ztemp_0_2 .
#
# :vav-cooling-only_name_0_3 a brick:VAV ;
#     rdfs:label "VAV" ;
#     brick:feeds :vav-cooling-only_zone_0_3 ;
#     brick:hasPart :vav-cooling-only_dmp_0_3 ;
#     brick:hasPoint :vav-cooling-only_co2_0_3,
#         :vav-cooling-only_dat_0_3,
#         :vav-cooling-only_occ_0_3,
#         :vav-cooling-only_ztemp_0_3 .
#
# :vav-cooling-only_name_0_4 a brick:VAV ;
#     rdfs:label "VAV" ;
#     brick:feeds :vav-cooling-only_zone_0_4 ;
#     brick:hasPart :vav-cooling-only_dmp_0_4 ;
#     brick:hasPoint :vav-cooling-only_co2_0_4,
#         :vav-cooling-only_dat_0_4,
#         :vav-cooling-only_occ_0_4,
#         :vav-cooling-only_ztemp_0_4 .
#
# :vav-cooling-only_name_0_5 a brick:VAV ;
#     rdfs:label "VAV" ;
#     brick:feeds :vav-cooling-only_zone_0_5 ;
#     brick:hasPart :vav-cooling-only_dmp_0_5 ;
#     brick:hasPoint :vav-cooling-only_co2_0_5,
#         :vav-cooling-only_dat_0_5,
#         :vav-cooling-only_occ_0_5,
#         :vav-cooling-only_ztemp_0_5 .
#
# :vav-cooling-only_name_0_6 a brick:VAV ;
#     rdfs:label "VAV" ;
#     brick:feeds :vav-cooling-only_zone_0_6 ;
#     brick:hasPart :vav-cooling-only_dmp_0_6 ;
#     brick:hasPoint :vav-cooling-only_co2_0_6,
#         :vav-cooling-only_dat_0_6,
#         :vav-cooling-only_occ_0_6,
#         :vav-cooling-only_ztemp_0_6 .
#
# :vav-cooling-only_name_0_7 a brick:VAV ;
#     rdfs:label "VAV" ;
#     brick:feeds :vav-cooling-only_zone_0_7 ;
#     brick:hasPart :vav-cooling-only_dmp_0_7 ;
#     brick:hasPoint :vav-cooling-only_co2_0_7,
#         :vav-cooling-only_dat_0_7,
#         :vav-cooling-only_occ_0_7,
#         :vav-cooling-only_ztemp_0_7 .
#
# :vav-cooling-only_name_0_8 a brick:VAV ;
#     rdfs:label "VAV" ;
#     brick:feeds :vav-cooling-only_zone_0_8 ;
#     brick:hasPart :vav-cooling-only_dmp_0_8 ;
#     brick:hasPoint :vav-cooling-only_co2_0_8,
#         :vav-cooling-only_dat_0_8,
#         :vav-cooling-only_occ_0_8,
#         :vav-cooling-only_ztemp_0_8 .
#
# :vav-cooling-only_name_0_9 a brick:VAV ;
#     rdfs:label "VAV" ;
#     brick:feeds :vav-cooling-only_zone_0_9 ;
#     brick:hasPart :vav-cooling-only_dmp_0_9 ;
#     brick:hasPoint :vav-cooling-only_co2_0_9,
#         :vav-cooling-only_dat_0_9,
#         :vav-cooling-only_occ_0_9,
#         :vav-cooling-only_ztemp_0_9 .
#
# :vav-cooling-only_name_1_0 a brick:VAV ;
#     rdfs:label "VAV" ;
#     brick:feeds :vav-cooling-only_zone_1_0 ;
#     brick:hasPart :vav-cooling-only_dmp_1_0 ;
#     brick:hasPoint :vav-cooling-only_co2_1_0,
#         :vav-cooling-only_dat_1_0,
#         :vav-cooling-only_occ_1_0,
#         :vav-cooling-only_ztemp_1_0 .
#
# :vav-cooling-only_name_1_1 a brick:VAV ;
#     rdfs:label "VAV" ;
#     brick:feeds :vav-cooling-only_zone_1_1 ;
#     brick:hasPart :vav-cooling-only_dmp_1_1 ;
#     brick:hasPoint :vav-cooling-only_co2_1_1,
#         :vav-cooling-only_dat_1_1,
#         :vav-cooling-only_occ_1_1,
#         :vav-cooling-only_ztemp_1_1 .
#
# :vav-cooling-only_name_1_10 a brick:VAV ;
#     rdfs:label "VAV" ;
#     brick:feeds :vav-cooling-only_zone_1_10 ;
#     brick:hasPart :vav-cooling-only_dmp_1_10 ;
#     brick:hasPoint :vav-cooling-only_co2_1_10,
#         :vav-cooling-only_dat_1_10,
#         :vav-cooling-only_occ_1_10,
#         :vav-cooling-only_ztemp_1_10 .
#
# :vav-cooling-only_name_1_11 a brick:VAV ;
#     rdfs:label "VAV" ;
#     brick:feeds :vav-cooling-only_zone_1_11 ;
#     brick:hasPart :vav-cooling-only_dmp_1_11 ;
#     brick:hasPoint :vav-cooling-only_co2_1_11,
#         :vav-cooling-only_dat_1_11,
#         :vav-cooling-only_occ_1_11,
#         :vav-cooling-only_ztemp_1_11 .
#
# :vav-cooling-only_name_1_12 a brick:VAV ;
#     rdfs:label "VAV" ;
#     brick:feeds :vav-cooling-only_zone_1_12 ;
#     brick:hasPart :vav-cooling-only_dmp_1_12 ;
#     brick:hasPoint :vav-cooling-only_co2_1_12,
#         :vav-cooling-only_dat_1_12,
#         :vav-cooling-only_occ_1_12,
#         :vav-cooling-only_ztemp_1_12 .
#
# :vav-cooling-only_name_1_13 a brick:VAV ;
#     rdfs:label "VAV" ;
#     brick:feeds :vav-cooling-only_zone_1_13 ;
#     brick:hasPart :vav-cooling-only_dmp_1_13 ;
#     brick:hasPoint :vav-cooling-only_co2_1_13,
#         :vav-cooling-only_dat_1_13,
#         :vav-cooling-only_occ_1_13,
#         :vav-cooling-only_ztemp_1_13 .
#
# :vav-cooling-only_name_1_14 a brick:VAV ;
#     rdfs:label "VAV" ;
#     brick:feeds :vav-cooling-only_zone_1_14 ;
#     brick:hasPart :vav-cooling-only_dmp_1_14 ;
#     brick:hasPoint :vav-cooling-only_co2_1_14,
#         :vav-cooling-only_dat_1_14,
#         :vav-cooling-only_occ_1_14,
#         :vav-cooling-only_ztemp_1_14 .
#
# :vav-cooling-only_name_1_2 a brick:VAV ;
#     rdfs:label "VAV" ;
#     brick:feeds :vav-cooling-only_zone_1_2 ;
#     brick:hasPart :vav-cooling-only_dmp_1_2 ;
#     brick:hasPoint :vav-cooling-only_co2_1_2,
#         :vav-cooling-only_dat_1_2,
#         :vav-cooling-only_occ_1_2,
#         :vav-cooling-only_ztemp_1_2 .
#
# :vav-cooling-only_name_1_3 a brick:VAV ;
# ...
#     brick:hasPart :vav-with-reheat_name-dmp_3_3,
#         :vav-with-reheat_rhc_3_3 ;
#     brick:hasPoint :vav-with-reheat_name-co2_3_3,
#         :vav-with-reheat_name-dat_3_3,
#         :vav-with-reheat_name-occ_3_3,
#         :vav-with-reheat_name-ztemp_3_3 .
#
# :vav-with-reheat_name_3_4 a brick:VAV ;
#     rdfs:label "VAV" ;
#     brick:feeds :vav-with-reheat_name-zone_3_4 ;
#     brick:hasPart :vav-with-reheat_name-dmp_3_4,
#         :vav-with-reheat_rhc_3_4 ;
#     brick:hasPoint :vav-with-reheat_name-co2_3_4,
#         :vav-with-reheat_name-dat_3_4,
#         :vav-with-reheat_name-occ_3_4,
#         :vav-with-reheat_name-ztemp_3_4 .
#
# :vav-with-reheat_name_3_5 a brick:VAV ;
#     rdfs:label "VAV" ;
#     brick:feeds :vav-with-reheat_name-zone_3_5 ;
#     brick:hasPart :vav-with-reheat_name-dmp_3_5,
#         :vav-with-reheat_rhc_3_5 ;
#     brick:hasPoint :vav-with-reheat_name-co2_3_5,
#         :vav-with-reheat_name-dat_3_5,
#         :vav-with-reheat_name-occ_3_5,
#         :vav-with-reheat_name-ztemp_3_5 .
#
# :vav-with-reheat_name_3_6 a brick:VAV ;
#     rdfs:label "VAV" ;
#     brick:feeds :vav-with-reheat_name-zone_3_6 ;
#     brick:hasPart :vav-with-reheat_name-dmp_3_6,
#         :vav-with-reheat_rhc_3_6 ;
#     brick:hasPoint :vav-with-reheat_name-co2_3_6,
#         :vav-with-reheat_name-dat_3_6,
#         :vav-with-reheat_name-occ_3_6,
#         :vav-with-reheat_name-ztemp_3_6 .
#
# :vav-with-reheat_name_3_7 a brick:VAV ;
#     rdfs:label "VAV" ;
#     brick:feeds :vav-with-reheat_name-zone_3_7 ;
#     brick:hasPart :vav-with-reheat_name-dmp_3_7,
#         :vav-with-reheat_rhc_3_7 ;
#     brick:hasPoint :vav-with-reheat_name-co2_3_7,
#         :vav-with-reheat_name-dat_3_7,
#         :vav-with-reheat_name-occ_3_7,
#         :vav-with-reheat_name-ztemp_3_7 .
#
# :vav-with-reheat_name_3_8 a brick:VAV ;
#     rdfs:label "VAV" ;
#     brick:feeds :vav-with-reheat_name-zone_3_8 ;
#     brick:hasPart :vav-with-reheat_name-dmp_3_8,
#         :vav-with-reheat_rhc_3_8 ;
#     brick:hasPoint :vav-with-reheat_name-co2_3_8,
#         :vav-with-reheat_name-dat_3_8,
#         :vav-with-reheat_name-occ_3_8,
#         :vav-with-reheat_name-ztemp_3_8 .
#
# :vav-with-reheat_name_3_9 a brick:VAV ;
#     rdfs:label "VAV" ;
#     brick:feeds :vav-with-reheat_name-zone_3_9 ;
#     brick:hasPart :vav-with-reheat_name-dmp_3_9,
#         :vav-with-reheat_rhc_3_9 ;
#     brick:hasPoint :vav-with-reheat_name-co2_3_9,
#         :vav-with-reheat_name-dat_3_9,
#         :vav-with-reheat_name-occ_3_9,
#         :vav-with-reheat_name-ztemp_3_9 .
#
# :vav-with-reheat_rhc-cmd_0_0 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_0_1 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_0_10 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_0_11 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_0_12 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_0_13 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_0_14 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_0_2 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_0_3 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_0_4 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_0_5 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_0_6 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_0_7 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_0_8 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_0_9 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_1_0 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_1_1 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_1_10 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_1_11 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_1_12 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_1_13 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_1_14 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_1_2 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_1_3 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_1_4 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_1_5 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_1_6 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_1_7 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_1_8 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_1_9 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_2_0 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_2_1 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_2_10 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_2_11 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_2_12 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_2_13 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_2_14 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_2_2 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_2_3 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_2_4 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_2_5 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_2_6 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_2_7 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_2_8 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_2_9 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_3_0 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_3_1 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_3_10 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_3_11 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_3_12 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_3_13 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_3_14 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_3_2 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_3_3 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_3_4 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_3_5 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_3_6 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_3_7 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_3_8 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc-cmd_3_9 a brick:Position_Command ;
#     rdfs:label "Position_Command" .
#
# :vav-with-reheat_rhc_0_0 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_0_0 .
#
# :vav-with-reheat_rhc_0_1 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_0_1 .
#
# :vav-with-reheat_rhc_0_10 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_0_10 .
#
# :vav-with-reheat_rhc_0_11 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_0_11 .
#
# :vav-with-reheat_rhc_0_12 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_0_12 .
#
# :vav-with-reheat_rhc_0_13 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_0_13 .
#
# :vav-with-reheat_rhc_0_14 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_0_14 .
#
# :vav-with-reheat_rhc_0_2 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_0_2 .
#
# :vav-with-reheat_rhc_0_3 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_0_3 .
#
# :vav-with-reheat_rhc_0_4 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_0_4 .
#
# :vav-with-reheat_rhc_0_5 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_0_5 .
#
# :vav-with-reheat_rhc_0_6 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_0_6 .
#
# :vav-with-reheat_rhc_0_7 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_0_7 .
#
# :vav-with-reheat_rhc_0_8 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_0_8 .
#
# :vav-with-reheat_rhc_0_9 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_0_9 .
#
# :vav-with-reheat_rhc_1_0 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_1_0 .
#
# :vav-with-reheat_rhc_1_1 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_1_1 .
#
# :vav-with-reheat_rhc_1_10 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_1_10 .
#
# :vav-with-reheat_rhc_1_11 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_1_11 .
#
# :vav-with-reheat_rhc_1_12 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_1_12 .
#
# :vav-with-reheat_rhc_1_13 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_1_13 .
#
# :vav-with-reheat_rhc_1_14 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_1_14 .
#
# :vav-with-reheat_rhc_1_2 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_1_2 .
#
# :vav-with-reheat_rhc_1_3 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_1_3 .
#
# :vav-with-reheat_rhc_1_4 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_1_4 .
#
# :vav-with-reheat_rhc_1_5 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_1_5 .
#
# :vav-with-reheat_rhc_1_6 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_1_6 .
#
# :vav-with-reheat_rhc_1_7 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_1_7 .
#
# :vav-with-reheat_rhc_1_8 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_1_8 .
#
# :vav-with-reheat_rhc_1_9 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_1_9 .
#
# :vav-with-reheat_rhc_2_0 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_2_0 .
#
# :vav-with-reheat_rhc_2_1 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_2_1 .
#
# :vav-with-reheat_rhc_2_10 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_2_10 .
#
# :vav-with-reheat_rhc_2_11 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_2_11 .
#
# :vav-with-reheat_rhc_2_12 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_2_12 .
#
# :vav-with-reheat_rhc_2_13 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_2_13 .
#
# :vav-with-reheat_rhc_2_14 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_2_14 .
#
# :vav-with-reheat_rhc_2_2 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_2_2 .
#
# :vav-with-reheat_rhc_2_3 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_2_3 .
#
# :vav-with-reheat_rhc_2_4 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_2_4 .
#
# :vav-with-reheat_rhc_2_5 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_2_5 .
#
# :vav-with-reheat_rhc_2_6 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_2_6 .
#
# :vav-with-reheat_rhc_2_7 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_2_7 .
#
# :vav-with-reheat_rhc_2_8 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_2_8 .
#
# :vav-with-reheat_rhc_2_9 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_2_9 .
#
# :vav-with-reheat_rhc_3_0 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_3_0 .
#
# :vav-with-reheat_rhc_3_1 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_3_1 .
#
# :vav-with-reheat_rhc_3_10 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_3_10 .
#
# :vav-with-reheat_rhc_3_11 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_3_11 .
#
# :vav-with-reheat_rhc_3_12 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_3_12 .
#
# :vav-with-reheat_rhc_3_13 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_3_13 .
#
# :vav-with-reheat_rhc_3_14 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_3_14 .
#
# :vav-with-reheat_rhc_3_2 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_3_2 .
#
# :vav-with-reheat_rhc_3_3 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_3_3 .
#
# :vav-with-reheat_rhc_3_4 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_3_4 .
#
# :vav-with-reheat_rhc_3_5 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_3_5 .
#
# :vav-with-reheat_rhc_3_6 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_3_6 .
#
# :vav-with-reheat_rhc_3_7 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_3_7 .
#
# :vav-with-reheat_rhc_3_8 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_3_8 .
#
# :vav-with-reheat_rhc_3_9 a brick:Heating_Coil ;
#     rdfs:label "Heating_Coil" ;
#     brick:hasPoint :vav-with-reheat_rhc-cmd_3_9 .

# %%
g.serialize('brick-example-parsed.ttl')
# Out:
# <Graph identifier=Naaebb14beb78490ab5037186f8ad59d6 (<class 'rdflib.graph.Graph'>)>

# %%
g = Graph()
g.parse('brick-example.ttl')
len(g)
# Out:
# 3429

# %%
g = Graph()
g.parse('s223-example.ttl')
len(g)
# Out:
# 6901
