# %% [markdown]
# Changing approaches
#
# Direct approaches to create bschema have too many compromises and aren't working generically.
#
# Should change approaches to use one hop graph queries and LLMs to do new class names, then can just create a class graph.
#
# This also has more interpretability than the bschema, where you still had to inspect the graph to learn what something is, instead of just looking at a human readable label.
#
# The amount of iterations of naming things based on their one hop graphs should also work for different schema or types of graphs so it is somewhat manual but also can be generalized.
#
#
# Two options:
#
# 1. can go through and create ask queries for each thing, then run the ask query on each node and see which node matches which query. Ask queries are pretty fast so this is probably faster than option 2. However, since ask queries will be correct for a subset of the query (i.e., they won't catch if there's MORE information for a given thing) this will require some correction at the end. Will essentially have to remove the vav-cooling-only label from vavs with reheat based on the fact that all vavs with reheat are also vav-cooling-only, so we can remove this. Can alternatively generate two sparql queries and test both directions
#
# 2. Can go through and check if class graphs are isomorphic for each thing.
#
# Then need to build the inferred class label.
#
# LLM class naming isn't particularly good using a locally running LLM. Should just number the variants of the original class. (ConnectionPoint1,2, VAV1,2, etc.)
#
# Using GPT OSS run by CBORG, creating new class names was decent
#
# # TODO:
# - works right for brick, but class graph currently only contains one class. This may create bugs, so I will need to consider other methods. Working so far because it happens to gets the most recently added class, which is alphabetically the latest because of the version tag I'm adding. Instead of directly doing the class relations it may make sense to separate instance and class once again
#
# - Fix how I'm getting aspects and named nodes again so these show up in class graph for isomorphism.

# %%
from rdflib.compare import isomorphic

from pprint import pprint
from typing import Union, List, Union, Tuple, Optional
from rdflib import Graph, URIRef
import sys

sys.path.append('../../utils')
sys.path.append('utils')

from namespaces import *
from utils import * 

from tqdm import tqdm

# %%
def get_subgraph_with_hops(
    graph: Graph, 
    central_node: Union[str, URIRef], 
    num_hops: int,
    get_classes = False
) -> Graph:
    """
    Extract a subgraph containing all triples within num_hops from central_node,
    including rdf:type information for all entities.
    
    Args:
        graph: The source RDF graph
        central_node: The central node URI (as string or URIRef)
        num_hops: Number of hops to traverse from the central node
    
    Returns:
        A new Graph containing the subgraph
    """
    if isinstance(central_node, str):
        # print("central node is string: ", central_node)
        central_node = URIRef(central_node)
    
    subgraph = Graph(store = 'Oxigraph')
    visited_nodes = set()
    current_layer = {central_node}
    
    # Add class information for central node
    for class_uri in graph.objects(central_node, RDF.type):
        subgraph.add((central_node, RDF.type, class_uri))
    
    for hop in range(num_hops):
        next_layer = set()
        
        for node in current_layer:
            if node in visited_nodes:
                continue
            visited_nodes.add(node)
            
            # Get triples where node is subject
            for p, o in graph.predicate_objects(node):
                subgraph.add((node, p, o))
                if isinstance(o, URIRef):
                    next_layer.add(o)
                    # Add class information for object
                    for class_uri in graph.objects(o, RDF.type):
                        subgraph.add((o, RDF.type, class_uri))
            
            # Get triples where node is object
            for s, p in graph.subject_predicates(node):
                subgraph.add((s, p, node))
                if isinstance(s, URIRef):
                    next_layer.add(s)
                    # Add class information for subject
                    for class_uri in graph.objects(s, RDF.type):
                        subgraph.add((s, RDF.type, class_uri))
        
        current_layer = next_layer
    if get_classes:
        for s, p, o in subgraph:
            for class_uri in graph.objects(s, RDF.type):
                subgraph.add((s, RDF.type, class_uri))
            for class_uri in graph.objects(o, RDF.type):
                subgraph.add((o, RDF.type, class_uri))
    return subgraph

# %%
def get_class(node: URIRef, data_graph) -> URIRef:
        """Get the class of a node from the data graph"""
        # TODO: Shouldn't hve a default class and need a union of classes
        # Should have something else to represent literals, other than resource, but need to make sure defualt just applies to literals
        for _, _, o in data_graph.triples((node, A, None)):
            return o
        return URIRef("http://www.w3.org/2000/01/rdf-schema#Resource")

def create_class_pattern(triple: Tuple[URIRef, URIRef, URIRef], data_graph) -> Tuple[URIRef, URIRef, URIRef]:
        """Create class-based pattern from concrete triples"""
        # may want to have a union of classes 
        # TODO: if ordering is not consistent of classes this could create bugs
        # subject node should maybe represent union of classes
        named_node_predicates = [S223.hasAspect, S223.hasEnumerationKind, S223.hasQuantityKind, S223.hasUnit, S223.hasMedium, S223.ofConstituent]
        s_class = get_class(triple[0], data_graph)
        if triple[1] == A:
            o_class = triple[2]
        elif triple[1] in [S223['hasAspect'], S223.hasEnumerationKind, S223.hasQuantityKind, S223.hasUnit]:
            o_class = triple[2]
        else:
            o_class = get_class(triple[2], data_graph)
        return (s_class, triple[1], o_class)

def create_class_graph(data_graph: Graph):
    class_graph = Graph(store = 'Oxigraph')
    for triple in data_graph: 
        class_triple = create_class_pattern(triple, data_graph)
        if class_triple in class_graph:
            continue
        else:
            class_graph.add(class_triple)

    return class_graph

def create_class_graph(data_graph: Graph):
    class_graph = Graph(store = 'Oxigraph')
    for triple in data_graph: 
        class_triple = create_class_pattern(triple, data_graph)
        if class_triple in class_graph:
            continue
        else:
            class_graph.add(class_triple)

    return class_graph

def get_class_isomorphisms(data_graph):
    distinct_class_subgraphs = []
    seen_subjects = set()
    equivalent_subjects = []
    subject_classes = []
    for s,p,o in tqdm(data_graph):
        add_subgraph = False
        found_in_preferred = False
        subject_class = get_class(s, data_graph)
        if s in seen_subjects:
            continue
        else:
            seen_subjects.add(s)
        subgraph = get_subgraph_with_hops(data_graph, s, 1)
        class_graph = create_class_graph(subgraph)
        if equivalent_subjects == []:
            equivalent_subjects.append([s])
            distinct_class_subgraphs.append(class_graph)
            subject_classes.append(subject_class)
            continue
            
        indices = [i for i, x in enumerate(subject_classes) if x == subject_class]
        # check indices first 
        for i in indices:
            g = distinct_class_subgraphs[i]
            if isomorphic(class_graph, g): 
                equivalent_subjects[i].append(s)
                found_in_preferred = True
                break

        if found_in_preferred:
            continue

        for i, g in enumerate(distinct_class_subgraphs):
            if isomorphic(class_graph, g): 
                equivalent_subjects[i].append(s)
                add_subgraph = False
                break
            else:
                add_subgraph = True
                
        if add_subgraph == True:
            distinct_class_subgraphs.append(class_graph)
            equivalent_subjects.append([s])
            subject_classes.append(subject_class)
    return distinct_class_subgraphs, seen_subjects, equivalent_subjects, subject_classes

# %%
def find_similar_sublists(list1, list2, min_intersection_ratio=0.4):
    """
    Find pairs of sublists that have high overlap but aren't exactly the same.
    
    Args:
        list1: First list containing sublists
        list2: Second list containing sublists
        min_intersection_ratio: Minimum ratio of intersection to consider (default 0.8)
    
    Returns:
        list: Pairs of similar but not identical sublists with their similarity info
    """
    similar_pairs = []
    
    for i, sublist1 in enumerate(list1):
        set1 = set(sublist1)
        
        for j, sublist2 in enumerate(list2):
            set2 = set(sublist2)
            
            # Skip if they're exactly the same
            if set1 == set2:
                continue
            
            # Calculate intersection and union
            intersection = set1 & set2
            union = set1 | set2
            
            # Calculate Jaccard similarity
            jaccard = len(intersection) / len(union) if union else 0
            
            # Also calculate intersection ratio relative to each set
            ratio1 = len(intersection) / len(set1) if set1 else 0
            ratio2 = len(intersection) / len(set2) if set2 else 0
            
            # Check if meets threshold
            if jaccard >= min_intersection_ratio:
                similar_pairs.append({
                    'list1_index': i,
                    'list2_index': j,
                    'jaccard_similarity': jaccard,
                    'intersection_size': len(intersection),
                    'only_in_list1': list(set1 - set2),
                    'only_in_list2': list(set2 - set1),
                    'common': list(intersection),
                    'size_list1': len(set1),
                    'size_list2': len(set2)
                })
    
    return similar_pairs

# Usage:
# similar = find_similar_sublists(your_list1, your_list2, min_intersection_ratio=0.8)
# 
# for pair in similar:
#     print(f"\nSublist {pair['list1_index']} from list1 and {pair['list2_index']} from list2:")
#     print(f"  Similarity: {pair['jaccard_similarity']:.2%}")
#     print(f"  Only in list1: {len(pair['only_in_list1'])} items")
#     print(f"  Only in list2: {len(pair['only_in_list2'])} items")

# %%
counter = {}

def lists_have_same_members(list1, list2):
    """Check if two lists with sublists have same members, regardless of order."""
    if len(list1) != len(list2):
        return False
    
    # Convert each sublist to a frozenset and compare as sets
    sets1 = {frozenset(sublist) for sublist in list1}
    sets2 = {frozenset(sublist) for sublist in list2}
    
    return sets1 == sets2

def copy_graph(g):
    g2 = Graph(store = "Oxigraph")
    bind_prefixes(g2)
    for triple in g:
        g2.add(triple)
    return g2

def create_new_class_name(cls_name):
    name = cls_name.split('#')[-1].split('_version_')[0]
    counter[name] = count = counter.get(name, 0) + 1
    return URIRef(f"{name}_version_{count}")

def assign_new_classes(data_graph, distinct_class_subgraphs, equivalent_subjects, subject_classes):
    class_mappings = {}
    new_subject_classes = {}
    for i, subj_list in enumerate(equivalent_subjects):
        new_cls_name = create_new_class_name(subject_classes[i])
        for s in subj_list:
            new_subject_classes.update({s: HPFS[new_cls_name.split('#')[-1]]})
            class_mappings[new_cls_name] = (subject_classes[i], distinct_class_subgraphs[i])

    return new_subject_classes, class_mappings

def run_algo(original_data_graph, iterations = 5):
    # need to remove ontology statement because having just the prefix breaks serialization/parsing by oxigraph
    global counter
    counter = {}
    class_mappings = []
    original_data_graph.remove((URIRef('urn:example#'), A, OWL.Ontology))
    data_graph = copy_graph(original_data_graph)
    for i in range(iterations):
        distinct_class_subgraphs, seen_subjects, equivalent_subjects, subject_classes = get_class_isomorphisms(data_graph)
        new_subject_classes, new_class_mappings = assign_new_classes(data_graph, distinct_class_subgraphs, equivalent_subjects, subject_classes)
        class_mappings.append(new_class_mappings)

        if i >= 1:
            # stop condition is no subjects are being distinguished from each other
            if lists_have_same_members(equivalent_subjects, prev_equivalent_subjects):
                print('Algorithm stopped, since no further distinguishing classes found. Process took ',i, 'iterations')
                print('Printing Last Set Difference')
                pprint(last_set_diff)
                break
            else:
                last_set_diff = find_similar_sublists(equivalent_subjects, prev_equivalent_subjects)
    
        prev_equivalent_subjects = equivalent_subjects
        for s, cls_name in new_subject_classes.items():
            data_graph.add((s, A, cls_name))


    class_graph = create_class_graph(data_graph)
    return class_graph, data_graph, class_mappings

# %%
data_graph = Graph(store = 'Oxigraph')
data_graph.parse("/Users/lazlopaul/Desktop/223p/experiments/graph-pattern-id/archive/development/brick-example.ttl", format="turtle")
# Out:
# <Graph identifier=Nc41beb90a38042c3a8f4d4543e2c654a (<class 'rdflib.graph.Graph'>)>

# %%
s223_data_graph = Graph(store = 'Oxigraph')
s223_data_graph.parse("/Users/lazlopaul/Desktop/223p/experiments/graph-pattern-id/archive/development/s223-example.ttl", format="turtle")
# Out:
# <Graph identifier=Nac4c85dd1055442c82373cd0f8ec971d (<class 'rdflib.graph.Graph'>)>

# %%
cg, dg, cm = run_algo(data_graph, 4)
cg.print()
# Out:
# 100%|██████████| 3428/3428 [00:00<00:00, 5399.89it/s]
# 100%|██████████| 4572/4572 [00:00<00:00, 5162.99it/s]
# 100%|██████████| 5716/5716 [00:01<00:00, 5278.02it/s]
# 100%|██████████| 6860/6860 [00:01<00:00, 5247.34it/s]
# Algorithm stopped, since no further distinguishing classes found. Process took  3 iterations
# Printing Last Set Difference
# [{'common': [rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_2'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_10'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_12'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_0'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_5'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_6'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_1'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_7'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_10'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_3'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_6'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_2'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_1'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_4'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_13'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_0'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_9'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_0'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_13'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_4'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_11'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_2'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_7'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_11'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_1'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_14'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_8'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_3'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_10'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_7'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_14'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_5'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_8'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_13'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_4'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_5'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_13'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_9'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_1'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_7'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_11'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_3'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_12'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_12'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_5'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_14'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_2'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_3'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_14'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_11'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_0'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_9'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_8'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_4'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_10'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_9'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_12'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_6'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_8'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_6')],
#   'intersection_size': 60,
#   'jaccard_similarity': 0.5,
#   'list1_index': 9,
#   'list2_index': 23,
#   'only_in_list1': [],
#   'only_in_list2': [rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_1'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_13'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_7'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_13'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_14'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_3'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_13'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_8'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_7'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_2'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_9'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_5'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_3'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_9'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_8'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_11'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_12'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_5'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_10'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_6'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_6'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_9'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_2'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_10'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_7'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_0'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_13'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_3'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_0'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_0'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_4'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_14'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_11'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_4'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_5'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_14'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_12'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_11'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_9'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_12'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_11'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_6'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_12'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_1'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_4'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_0'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_14'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_10'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_1'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_8'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_1'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_7'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_5'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_4'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_2'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_2'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_10'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_6'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_8'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_3')],
#   'size_list1': 60,
#   'size_list2': 120},
#  {'common': [rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_1'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_13'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_7'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_13'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_14'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_3'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_13'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_2'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_8'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_7'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_9'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_5'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_9'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_3'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_11'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_5'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_12'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_8'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_10'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_6'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_6'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_2'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_9'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_10'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_7'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_0'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_13'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_0'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_3'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_0'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_4'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_11'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_14'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_4'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_14'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_5'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_12'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_12'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_11'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_1'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_9'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_11'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_12'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_6'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_4'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_0'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_14'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_1'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_1'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_8'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_10'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_5'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_7'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_4'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_2'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_2'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_10'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_6'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_8'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_3')],
#   'intersection_size': 60,
#   'jaccard_similarity': 0.5,
#   'list1_index': 10,
#   'list2_index': 23,
#   'only_in_list1': [],
#   'only_in_list2': [rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_2'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_10'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_3'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_12'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_5'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_0'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_7'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_1'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_10'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_6'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_6'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_2'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_1'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_4'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_13'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_9'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_0'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_0'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_13'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_4'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_2'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_11'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_7'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_11'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_1'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_14'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_8'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_3'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_10'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_7'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_14'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_5'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_8'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_13'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_4'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_5'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_13'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_9'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_1'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_7'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_11'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_3'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_12'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_12'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_5'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_14'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_2'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_3'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_14'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_9'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_11'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_0'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_8'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_12'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_4'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_10'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_9'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_6'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_8'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_6')],
#   'size_list1': 60,
#   'size_list2': 120}]
# @prefix brick: <https://brickschema.org/schema/Brick#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# <urn:hpflex/shapes#AHU_version_3> a brick:AHU,
#         <urn:hpflex/shapes#AHU_version_1>,
#         <urn:hpflex/shapes#AHU_version_2>,
#         <urn:hpflex/shapes#AHU_version_3> ;
#     rdfs:label rdfs:Resource ;
#     brick:feeds <urn:hpflex/shapes#VAV_version_5>,
#         <urn:hpflex/shapes#VAV_version_6> ;
#     brick:hasPart <urn:hpflex/shapes#Cooling_Coil_version_3>,
#         <urn:hpflex/shapes#Damper_version_6>,
#         <urn:hpflex/shapes#Heating_Coil_version_5>,
#         <urn:hpflex/shapes#Supply_Fan_version_3> ;
#     brick:hasPoint <urn:hpflex/shapes#Filter_Differential_Pressure_Sensor_version_3>,
#         <urn:hpflex/shapes#Mixed_Air_Temperature_Sensor_version_3>,
#         <urn:hpflex/shapes#Outside_Air_Temperature_Sensor_version_3>,
#         <urn:hpflex/shapes#Return_Air_Temperature_Sensor_version_3>,
#         <urn:hpflex/shapes#Supply_Air_Temperature_Sensor_version_3> .
#
# <urn:hpflex/shapes#CO2_Level_Sensor_version_4> a brick:CO2_Level_Sensor,
#         <urn:hpflex/shapes#CO2_Level_Sensor_version_1>,
#         <urn:hpflex/shapes#CO2_Level_Sensor_version_3>,
#         <urn:hpflex/shapes#CO2_Level_Sensor_version_4> ;
#     rdfs:label rdfs:Resource .
#
# <urn:hpflex/shapes#CO2_Level_Sensor_version_5> a brick:CO2_Level_Sensor,
#         <urn:hpflex/shapes#CO2_Level_Sensor_version_1>,
#         <urn:hpflex/shapes#CO2_Level_Sensor_version_2>,
#         <urn:hpflex/shapes#CO2_Level_Sensor_version_5> ;
#     rdfs:label rdfs:Resource .
#
# <urn:hpflex/shapes#Cooling_Coil_version_3> a brick:Cooling_Coil,
#         <urn:hpflex/shapes#Cooling_Coil_version_1>,
#         <urn:hpflex/shapes#Cooling_Coil_version_2>,
#         <urn:hpflex/shapes#Cooling_Coil_version_3> ;
#     rdfs:label rdfs:Resource ;
#     brick:hasPoint <urn:hpflex/shapes#Valve_Position_Command_version_5> .
#
# <urn:hpflex/shapes#Damper_Position_Command_version_4> a brick:Damper_Position_Command,
#         <urn:hpflex/shapes#Damper_Position_Command_version_1>,
#         <urn:hpflex/shapes#Damper_Position_Command_version_3>,
#         <urn:hpflex/shapes#Damper_Position_Command_version_4> ;
#     rdfs:label rdfs:Resource .
#
# <urn:hpflex/shapes#Damper_Position_Command_version_5> a brick:Damper_Position_Command,
#         <urn:hpflex/shapes#Damper_Position_Command_version_1>,
#         <urn:hpflex/shapes#Damper_Position_Command_version_2>,
#         <urn:hpflex/shapes#Damper_Position_Command_version_5> ;
#     rdfs:label rdfs:Resource .
#
# <urn:hpflex/shapes#Damper_Position_Command_version_6> a brick:Damper_Position_Command,
#         <urn:hpflex/shapes#Damper_Position_Command_version_1>,
#         <urn:hpflex/shapes#Damper_Position_Command_version_2>,
#         <urn:hpflex/shapes#Damper_Position_Command_version_6> ;
#     rdfs:label rdfs:Resource .
#
# <urn:hpflex/shapes#Damper_version_6> a brick:Damper,
#         <urn:hpflex/shapes#Damper_version_1>,
#         <urn:hpflex/shapes#Damper_version_5>,
#         <urn:hpflex/shapes#Damper_version_6> ;
#     rdfs:label rdfs:Resource ;
#     brick:hasPoint <urn:hpflex/shapes#Damper_Position_Command_version_4> .
#
# <urn:hpflex/shapes#Damper_version_7> a brick:Damper,
#         <urn:hpflex/shapes#Damper_version_2>,
#         <urn:hpflex/shapes#Damper_version_4>,
#         <urn:hpflex/shapes#Damper_version_7> ;
#     rdfs:label rdfs:Resource ;
#     brick:hasPoint <urn:hpflex/shapes#Damper_Position_Command_version_5> .
#
# <urn:hpflex/shapes#Damper_version_8> a brick:Damper,
#         <urn:hpflex/shapes#Damper_version_2>,
#         <urn:hpflex/shapes#Damper_version_3>,
#         <urn:hpflex/shapes#Damper_version_8> ;
#     rdfs:label rdfs:Resource ;
#     brick:hasPoint <urn:hpflex/shapes#Damper_Position_Command_version_6> .
#
# <urn:hpflex/shapes#Discharge_Air_Temperature_Sensor_version_4> a brick:Discharge_Air_Temperature_Sensor,
#         <urn:hpflex/shapes#Discharge_Air_Temperature_Sensor_version_1>,
#         <urn:hpflex/shapes#Discharge_Air_Temperature_Sensor_version_3>,
#         <urn:hpflex/shapes#Discharge_Air_Temperature_Sensor_version_4> ;
#     rdfs:label rdfs:Resource .
#
# <urn:hpflex/shapes#Discharge_Air_Temperature_Sensor_version_5> a brick:Discharge_Air_Temperature_Sensor,
#         <urn:hpflex/shapes#Discharge_Air_Temperature_Sensor_version_1>,
#         <urn:hpflex/shapes#Discharge_Air_Temperature_Sensor_version_2>,
#         <urn:hpflex/shapes#Discharge_Air_Temperature_Sensor_version_5> ;
#     rdfs:label rdfs:Resource .
#
# <urn:hpflex/shapes#Fan_Status_version_3> a brick:Fan_Status,
#         <urn:hpflex/shapes#Fan_Status_version_1>,
#         <urn:hpflex/shapes#Fan_Status_version_2>,
#         <urn:hpflex/shapes#Fan_Status_version_3> ;
#     rdfs:label rdfs:Resource .
#
# <urn:hpflex/shapes#Filter_Differential_Pressure_Sensor_version_3> a brick:Filter_Differential_Pressure_Sensor,
#         <urn:hpflex/shapes#Filter_Differential_Pressure_Sensor_version_1>,
#         <urn:hpflex/shapes#Filter_Differential_Pressure_Sensor_version_2>,
#         <urn:hpflex/shapes#Filter_Differential_Pressure_Sensor_version_3> ;
#     rdfs:label rdfs:Resource .
#
# <urn:hpflex/shapes#Frequency_Command_version_3> a brick:Frequency_Command,
#         <urn:hpflex/shapes#Frequency_Command_version_1>,
#         <urn:hpflex/shapes#Frequency_Command_version_2>,
#         <urn:hpflex/shapes#Frequency_Command_version_3> ;
#     rdfs:label rdfs:Resource .
#
# <urn:hpflex/shapes#HVAC_Zone_version_4> a brick:HVAC_Zone,
#         <urn:hpflex/shapes#HVAC_Zone_version_1>,
#         <urn:hpflex/shapes#HVAC_Zone_version_3>,
#         <urn:hpflex/shapes#HVAC_Zone_version_4> ;
#     rdfs:label rdfs:Resource .
#
# <urn:hpflex/shapes#HVAC_Zone_version_5> a brick:HVAC_Zone,
#         <urn:hpflex/shapes#HVAC_Zone_version_1>,
#         <urn:hpflex/shapes#HVAC_Zone_version_2>,
#         <urn:hpflex/shapes#HVAC_Zone_version_5> ;
#     rdfs:label rdfs:Resource .
#
# <urn:hpflex/shapes#Heating_Coil_version_5> a brick:Heating_Coil,
#         <urn:hpflex/shapes#Heating_Coil_version_1>,
#         <urn:hpflex/shapes#Heating_Coil_version_4>,
#         <urn:hpflex/shapes#Heating_Coil_version_5> ;
#     rdfs:label rdfs:Resource ;
#     brick:hasPoint <urn:hpflex/shapes#Valve_Position_Command_version_6> .
#
# <urn:hpflex/shapes#Heating_Coil_version_6> a brick:Heating_Coil,
#         <urn:hpflex/shapes#Heating_Coil_version_2>,
#         <urn:hpflex/shapes#Heating_Coil_version_3>,
#         <urn:hpflex/shapes#Heating_Coil_version_6> ;
#     rdfs:label rdfs:Resource ;
#     brick:hasPoint <urn:hpflex/shapes#Position_Command_version_3> .
#
# <urn:hpflex/shapes#Mixed_Air_Temperature_Sensor_version_3> a brick:Mixed_Air_Temperature_Sensor,
#         <urn:hpflex/shapes#Mixed_Air_Temperature_Sensor_version_1>,
#         <urn:hpflex/shapes#Mixed_Air_Temperature_Sensor_version_2>,
#         <urn:hpflex/shapes#Mixed_Air_Temperature_Sensor_version_3> ;
#     rdfs:label rdfs:Resource .
#
# <urn:hpflex/shapes#Occupancy_Sensor_version_4> a brick:Occupancy_Sensor,
#         <urn:hpflex/shapes#Occupancy_Sensor_version_1>,
#         <urn:hpflex/shapes#Occupancy_Sensor_version_3>,
#         <urn:hpflex/shapes#Occupancy_Sensor_version_4> ;
#     rdfs:label rdfs:Resource .
#
# <urn:hpflex/shapes#Occupancy_Sensor_version_5> a brick:Occupancy_Sensor,
#         <urn:hpflex/shapes#Occupancy_Sensor_version_1>,
#         <urn:hpflex/shapes#Occupancy_Sensor_version_2>,
#         <urn:hpflex/shapes#Occupancy_Sensor_version_5> ;
#     rdfs:label rdfs:Resource .
#
# <urn:hpflex/shapes#Outside_Air_Temperature_Sensor_version_3> a brick:Outside_Air_Temperature_Sensor,
#         <urn:hpflex/shapes#Outside_Air_Temperature_Sensor_version_1>,
#         <urn:hpflex/shapes#Outside_Air_Temperature_Sensor_version_2>,
#         <urn:hpflex/shapes#Outside_Air_Temperature_Sensor_version_3> ;
#     rdfs:label rdfs:Resource .
#
# <urn:hpflex/shapes#Position_Command_version_3> a brick:Position_Command,
#         <urn:hpflex/shapes#Position_Command_version_1>,
#         <urn:hpflex/shapes#Position_Command_version_2>,
#         <urn:hpflex/shapes#Position_Command_version_3> ;
#     rdfs:label rdfs:Resource .
#
# <urn:hpflex/shapes#Return_Air_Temperature_Sensor_version_3> a brick:Return_Air_Temperature_Sensor,
#         <urn:hpflex/shapes#Return_Air_Temperature_Sensor_version_1>,
#         <urn:hpflex/shapes#Return_Air_Temperature_Sensor_version_2>,
#         <urn:hpflex/shapes#Return_Air_Temperature_Sensor_version_3> ;
#     rdfs:label rdfs:Resource .
#
# <urn:hpflex/shapes#Start_Stop_Command_version_3> a brick:Start_Stop_Command,
#         <urn:hpflex/shapes#Start_Stop_Command_version_1>,
#         <urn:hpflex/shapes#Start_Stop_Command_version_2>,
#         <urn:hpflex/shapes#Start_Stop_Command_version_3> ;
#     rdfs:label rdfs:Resource .
#
# <urn:hpflex/shapes#Supply_Air_Temperature_Sensor_version_3> a brick:Supply_Air_Temperature_Sensor,
#         <urn:hpflex/shapes#Supply_Air_Temperature_Sensor_version_1>,
#         <urn:hpflex/shapes#Supply_Air_Temperature_Sensor_version_2>,
#         <urn:hpflex/shapes#Supply_Air_Temperature_Sensor_version_3> ;
#     rdfs:label rdfs:Resource .
#
# <urn:hpflex/shapes#Supply_Fan_version_3> a brick:Supply_Fan,
#         <urn:hpflex/shapes#Supply_Fan_version_1>,
#         <urn:hpflex/shapes#Supply_Fan_version_2>,
#         <urn:hpflex/shapes#Supply_Fan_version_3> ;
#     rdfs:label rdfs:Resource ;
#     brick:hasPoint <urn:hpflex/shapes#Fan_Status_version_3>,
#         <urn:hpflex/shapes#Frequency_Command_version_3>,
#         <urn:hpflex/shapes#Start_Stop_Command_version_3> .
#
# <urn:hpflex/shapes#VAV_version_5> a brick:VAV,
#         <urn:hpflex/shapes#VAV_version_1>,
#         <urn:hpflex/shapes#VAV_version_4>,
#         <urn:hpflex/shapes#VAV_version_5> ;
#     rdfs:label rdfs:Resource ;
#     brick:feeds <urn:hpflex/shapes#HVAC_Zone_version_4> ;
#     brick:hasPart <urn:hpflex/shapes#Damper_version_7> ;
#     brick:hasPoint <urn:hpflex/shapes#CO2_Level_Sensor_version_4>,
#         <urn:hpflex/shapes#Discharge_Air_Temperature_Sensor_version_4>,
#         <urn:hpflex/shapes#Occupancy_Sensor_version_4>,
#         <urn:hpflex/shapes#Zone_Air_Temperature_Sensor_version_4> .
#
# <urn:hpflex/shapes#VAV_version_6> a brick:VAV,
#         <urn:hpflex/shapes#VAV_version_2>,
#         <urn:hpflex/shapes#VAV_version_3>,
#         <urn:hpflex/shapes#VAV_version_6> ;
#     rdfs:label rdfs:Resource ;
#     brick:feeds <urn:hpflex/shapes#HVAC_Zone_version_5> ;
#     brick:hasPart <urn:hpflex/shapes#Damper_version_8>,
#         <urn:hpflex/shapes#Heating_Coil_version_6> ;
#     brick:hasPoint <urn:hpflex/shapes#CO2_Level_Sensor_version_5>,
#         <urn:hpflex/shapes#Discharge_Air_Temperature_Sensor_version_5>,
#         <urn:hpflex/shapes#Occupancy_Sensor_version_5>,
#         <urn:hpflex/shapes#Zone_Air_Temperature_Sensor_version_5> .
#
# <urn:hpflex/shapes#Valve_Position_Command_version_5> a brick:Valve_Position_Command,
#         <urn:hpflex/shapes#Valve_Position_Command_version_1>,
#         <urn:hpflex/shapes#Valve_Position_Command_version_4>,
#         <urn:hpflex/shapes#Valve_Position_Command_version_5> ;
#     rdfs:label rdfs:Resource .
#
# <urn:hpflex/shapes#Valve_Position_Command_version_6> a brick:Valve_Position_Command,
#         <urn:hpflex/shapes#Valve_Position_Command_version_2>,
#         <urn:hpflex/shapes#Valve_Position_Command_version_3>,
#         <urn:hpflex/shapes#Valve_Position_Command_version_6> ;
#     rdfs:label rdfs:Resource .
#
# <urn:hpflex/shapes#Zone_Air_Temperature_Sensor_version_4> a brick:Zone_Air_Temperature_Sensor,
#         <urn:hpflex/shapes#Zone_Air_Temperature_Sensor_version_1>,
#         <urn:hpflex/shapes#Zone_Air_Temperature_Sensor_version_3>,
#         <urn:hpflex/shapes#Zone_Air_Temperature_Sensor_version_4> ;
#     rdfs:label rdfs:Resource .
#
# <urn:hpflex/shapes#Zone_Air_Temperature_Sensor_version_5> a brick:Zone_Air_Temperature_Sensor,
#         <urn:hpflex/shapes#Zone_Air_Temperature_Sensor_version_1>,
#         <urn:hpflex/shapes#Zone_Air_Temperature_Sensor_version_2>,
#         <urn:hpflex/shapes#Zone_Air_Temperature_Sensor_version_5> ;
#     rdfs:label rdfs:Resource .

# %%
# sorting through to look pritier
for s,p,o in cg:
    if (p == A) & (str(HPFS) in str(o)):
        cg.remove((s,p,o))
    if p == RDFS.label:
        cg.remove((s,p,o))
bind_prefixes(cg)
cg.serialize('algo5-brick.ttl')
# Out:
# <Graph identifier=N7aa1853142bc4e33aa50b78393726cbd (<class 'rdflib.graph.Graph'>)>

# %%
cg, dg, cm = run_algo(s223_data_graph, 5)
cg.print()
# Out:
# 100%|██████████| 6944/6944 [00:01<00:00, 4412.95it/s]
# 100%|██████████| 8480/8480 [00:01<00:00, 5601.81it/s]
# 100%|██████████| 10016/10016 [00:01<00:00, 5462.82it/s]
# 100%|██████████| 11552/11552 [00:02<00:00, 5338.39it/s]
# Algorithm stopped, since no further distinguishing classes found. Process took  3 iterations
# Printing Last Set Difference
# [{'common': [rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_2'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_10'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_12'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_0'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_5'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_6'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_1'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_7'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_10'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_3'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_6'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_2'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_1'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_4'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_13'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_0'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_9'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_0'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_13'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_4'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_11'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_2'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_7'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_11'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_1'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_14'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_8'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_3'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_10'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_7'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_14'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_5'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_8'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_13'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_4'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_5'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_13'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_9'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_1'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_7'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_11'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_3'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_12'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_12'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_5'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_14'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_2'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_3'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_14'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_11'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_0'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_9'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_8'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_4'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_10'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_9'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_12'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_6'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_8'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_6')],
#   'intersection_size': 60,
#   'jaccard_similarity': 0.5,
#   'list1_index': 5,
#   'list2_index': 39,
#   'only_in_list1': [],
#   'only_in_list2': [rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_1'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_13'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_7'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_13'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_14'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_3'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_13'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_8'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_7'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_2'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_9'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_5'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_3'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_9'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_8'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_11'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_12'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_5'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_10'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_6'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_6'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_9'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_2'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_10'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_7'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_0'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_13'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_3'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_0'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_0'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_4'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_14'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_11'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_4'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_5'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_14'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_12'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_11'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_9'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_12'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_11'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_6'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_12'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_1'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_4'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_0'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_14'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_10'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_1'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_8'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_1'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_7'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_5'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_4'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_2'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_2'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_10'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_6'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_8'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_3')],
#   'size_list1': 60,
#   'size_list2': 120},
#  {'common': [rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_1'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_13'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_7'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_13'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_14'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_3'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_13'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_2'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_8'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_7'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_9'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_5'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_9'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_3'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_11'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_5'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_12'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_8'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_10'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_6'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_6'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_2'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_9'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_10'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_7'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_0'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_13'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_0'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_3'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_0'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_4'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_11'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_14'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_4'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_14'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_5'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_12'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_12'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_11'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_1'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_9'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_11'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_12'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_6'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_4'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_0'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_14'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_1'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_1'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_8'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_10'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_5'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_7'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_4'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_2'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_2'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_10'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_6'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_8'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_3')],
#   'intersection_size': 60,
#   'jaccard_similarity': 0.5,
#   'list1_index': 6,
#   'list2_index': 39,
#   'only_in_list1': [],
#   'only_in_list2': [rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_2'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_10'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_3'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_12'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_5'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_0'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_7'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_1'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_10'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_6'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_6'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_2'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_1'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_4'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_13'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_9'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_0'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_0'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_13'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_4'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_2'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_11'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_7'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_11'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_1'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_14'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_8'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_3'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_10'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_7'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_14'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_5'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_8'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_13'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_4'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_5'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_13'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_9'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_1'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_7'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_11'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_3'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_12'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_12'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_5'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_14'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_2'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_3'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_14'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_9'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_11'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_0'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_8'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_12'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_4'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_10'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_9'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_1_6'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_0_8'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_2_6')],
#   'size_list1': 60,
#   'size_list2': 120},
#  {'common': [rdflib.term.URIRef('urn:example#vav-cooling-only_dat_1_3'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_2_7'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_1_0'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_1_13'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_1_2'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_3_14'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_1_1'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_2_8'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_0_5'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_3_3'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_0_14'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_3_11'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_0_2'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_2_12'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_3_4'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_0_13'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_3_9'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_2_2'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_2_11'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_2_13'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_0_3'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_0_6'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_1_6'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_3_6'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_1_5'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_2_1'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_2_6'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_3_0'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_3_7'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_2_4'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_0_9'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_2_3'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_1_12'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_0_0'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_2_10'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_3_5'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_0_4'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_0_8'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_3_1'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_0_10'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_0_11'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_0_7'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_1_9'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_2_0'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_2_5'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_3_8'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_1_14'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_0_1'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_1_7'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_1_11'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_0_12'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_1_8'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_1_4'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_3_12'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_3_13'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_2_14'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_2_9'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_1_10'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_3_10'),
#              rdflib.term.URIRef('urn:example#vav-cooling-only_dat_3_2')],
#   'intersection_size': 60,
#   'jaccard_similarity': 0.5,
#   'list1_index': 14,
#   'list2_index': 31,
#   'only_in_list1': [],
#   'only_in_list2': [rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_3_8'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_0_5'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_1_9'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_1_8'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_1_4'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_1_14'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_1_5'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_1_10'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_0_3'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_2_13'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_0_2'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_3_10'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_0_7'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_2_5'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_0_4'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_3_4'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_1_11'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_3_7'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_0_8'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_3_9'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_2_4'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_1_13'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_0_12'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_3_5'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_3_6'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_2_9'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_2_12'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_3_3'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_2_0'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_1_1'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_0_10'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_3_14'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_1_3'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_3_1'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_2_1'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_2_2'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_0_1'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_2_11'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_0_11'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_1_2'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_3_2'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_3_12'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_1_12'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_2_3'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_2_6'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_1_0'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_3_11'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_2_8'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_0_13'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_0_9'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_0_6'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_2_14'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_0_14'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_1_6'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_2_10'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_2_7'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_0_0'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_1_7'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_3_13'),
#                     rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_3_0')],
#   'size_list1': 60,
#   'size_list2': 120},
#  {'common': [rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_3_8'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_0_5'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_1_9'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_1_8'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_1_14'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_1_4'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_1_10'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_1_5'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_0_3'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_2_13'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_0_2'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_2_5'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_0_7'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_3_10'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_0_4'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_3_4'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_1_11'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_3_7'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_0_8'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_3_9'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_2_4'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_1_13'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_0_12'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_2_9'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_3_5'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_3_6'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_2_12'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_3_3'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_2_0'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_0_10'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_1_1'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_3_14'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_1_3'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_3_1'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_2_1'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_2_2'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_0_1'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_2_11'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_0_11'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_1_2'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_3_2'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_1_12'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_2_3'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_3_12'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_2_6'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_1_0'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_1_6'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_0_6'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_0_13'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_0_9'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_2_14'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_2_8'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_0_14'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_3_11'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_2_10'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_2_7'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_0_0'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_1_7'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_3_13'),
#              rdflib.term.URIRef('urn:example#vav-with-reheat_name-dat_3_0')],
#   'intersection_size': 60,
#   'jaccard_similarity': 0.5,
#   'list1_index': 15,
#   'list2_index': 31,
#   'only_in_list1': [],
#   'only_in_list2': [rdflib.term.URIRef('urn:example#vav-cooling-only_dat_1_3'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_2_7'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_1_0'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_1_13'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_1_2'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_3_14'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_1_1'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_2_8'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_0_14'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_0_5'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_3_3'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_3_11'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_0_2'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_2_12'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_3_4'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_0_13'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_3_9'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_2_2'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_2_11'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_3_6'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_0_3'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_2_13'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_1_6'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_0_6'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_1_5'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_2_1'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_2_6'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_3_7'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_3_0'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_2_4'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_0_9'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_2_3'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_2_10'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_0_0'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_3_5'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_1_12'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_0_4'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_3_1'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_0_8'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_0_11'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_2_5'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_0_7'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_2_0'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_0_10'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_1_9'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_3_8'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_1_14'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_0_1'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_1_7'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_1_8'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_3_12'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_3_13'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_0_12'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_1_11'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_1_4'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_2_14'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_2_9'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_1_10'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_3_10'),
#                     rdflib.term.URIRef('urn:example#vav-cooling-only_dat_3_2')],
#   'size_list1': 60,
#   'size_list2': 120}]
# @prefix ns1: <http://data.ashrae.org/standard223#> .
# @prefix ns2: <http://qudt.org/schema/qudt/> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# <urn:hpflex/shapes#DomainSpace_version_3> a ns1:DomainSpace,
#         <urn:hpflex/shapes#DomainSpace_version_1>,
#         <urn:hpflex/shapes#DomainSpace_version_2>,
#         <urn:hpflex/shapes#DomainSpace_version_3> ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasDomain rdfs:Resource .
#
# <urn:hpflex/shapes#Damper_version_6> a ns1:Damper,
#         <urn:hpflex/shapes#Damper_version_1>,
#         <urn:hpflex/shapes#Damper_version_5>,
#         <urn:hpflex/shapes#Damper_version_6> ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasProperty <urn:hpflex/shapes#QuantifiableActuatableProperty_version_7> .
#
# <urn:hpflex/shapes#Damper_version_7> a ns1:Damper,
#         <urn:hpflex/shapes#Damper_version_1>,
#         <urn:hpflex/shapes#Damper_version_4>,
#         <urn:hpflex/shapes#Damper_version_7> ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasProperty <urn:hpflex/shapes#QuantifiableActuatableProperty_version_8> .
#
# <urn:hpflex/shapes#InletConnectionPoint_version_11> a ns1:InletConnectionPoint,
#         <urn:hpflex/shapes#InletConnectionPoint_version_1>,
#         <urn:hpflex/shapes#InletConnectionPoint_version_10>,
#         <urn:hpflex/shapes#InletConnectionPoint_version_11> ;
#     rdfs:label rdfs:Resource ;
#     ns1:cnx <urn:hpflex/shapes#Coil_version_7> ;
#     ns1:hasMedium rdfs:Resource .
#
# <urn:hpflex/shapes#OutletConnectionPoint_version_18> a ns1:OutletConnectionPoint,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_1>,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_17>,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_18> ;
#     rdfs:label rdfs:Resource ;
#     ns1:cnx <urn:hpflex/shapes#Coil_version_9> ;
#     ns1:hasMedium rdfs:Resource ;
#     ns1:mapsTo <urn:hpflex/shapes#OutletConnectionPoint_version_24> .
#
# <urn:hpflex/shapes#OutletConnectionPoint_version_19> a ns1:OutletConnectionPoint,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_16>,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_19>,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_2> ;
#     rdfs:label rdfs:Resource ;
#     ns1:cnx <urn:hpflex/shapes#SingleDuctTerminal_version_5> ;
#     ns1:hasMedium rdfs:Resource ;
#     ns1:hasProperty <urn:hpflex/shapes#QuantifiableObservableProperty_version_29> .
#
# <urn:hpflex/shapes#OutletConnectionPoint_version_20> a ns1:OutletConnectionPoint,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_15>,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_2>,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_20> ;
#     rdfs:label rdfs:Resource ;
#     ns1:cnx <urn:hpflex/shapes#SingleDuctTerminal_version_6> ;
#     ns1:hasMedium rdfs:Resource ;
#     ns1:hasProperty <urn:hpflex/shapes#QuantifiableObservableProperty_version_30> .
#
# <urn:hpflex/shapes#OutletConnectionPoint_version_21> a ns1:OutletConnectionPoint,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_14>,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_21>,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_3> ;
#     rdfs:label rdfs:Resource ;
#     ns1:cnx <urn:hpflex/shapes#Coil_version_7> ;
#     ns1:hasMedium rdfs:Resource .
#
# <urn:hpflex/shapes#QuantifiableActuatableProperty_version_6> a ns1:QuantifiableActuatableProperty,
#         <urn:hpflex/shapes#QuantifiableActuatableProperty_version_1>,
#         <urn:hpflex/shapes#QuantifiableActuatableProperty_version_5>,
#         <urn:hpflex/shapes#QuantifiableActuatableProperty_version_6> ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasQuantityKind <http://qudt.org/vocab/quantitykind/PositionRatio> .
#
# <urn:hpflex/shapes#QuantifiableActuatableProperty_version_7> a ns1:QuantifiableActuatableProperty,
#         <urn:hpflex/shapes#QuantifiableActuatableProperty_version_1>,
#         <urn:hpflex/shapes#QuantifiableActuatableProperty_version_4>,
#         <urn:hpflex/shapes#QuantifiableActuatableProperty_version_7> ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasQuantityKind <http://qudt.org/vocab/quantitykind/PositionRatio> .
#
# <urn:hpflex/shapes#QuantifiableActuatableProperty_version_8> a ns1:QuantifiableActuatableProperty,
#         <urn:hpflex/shapes#QuantifiableActuatableProperty_version_1>,
#         <urn:hpflex/shapes#QuantifiableActuatableProperty_version_4>,
#         <urn:hpflex/shapes#QuantifiableActuatableProperty_version_8> ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasQuantityKind <http://qudt.org/vocab/quantitykind/PositionRatio> .
#
# <urn:hpflex/shapes#QuantifiableActuatableProperty_version_9> a ns1:QuantifiableActuatableProperty,
#         <urn:hpflex/shapes#QuantifiableActuatableProperty_version_2>,
#         <urn:hpflex/shapes#QuantifiableActuatableProperty_version_3>,
#         <urn:hpflex/shapes#QuantifiableActuatableProperty_version_9> ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasQuantityKind <http://qudt.org/vocab/quantitykind/PositionRatio> .
#
# <urn:hpflex/shapes#QuantifiableObservableProperty_version_22> a ns1:QuantifiableObservableProperty,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_1>,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_21>,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_22> ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasAspect ns1:Aspect-Filter ;
#     ns1:hasQuantityKind <http://qudt.org/vocab/quantitykind/PressureDifference> .
#
# <urn:hpflex/shapes#QuantifiableObservableProperty_version_23> a ns1:QuantifiableObservableProperty,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_2>,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_20>,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_23> ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasQuantityKind <http://qudt.org/vocab/quantitykind/Temperature> .
#
# <urn:hpflex/shapes#QuantifiableObservableProperty_version_24> a ns1:QuantifiableObservableProperty,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_19>,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_24>,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_3> ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasAspect ns1:Role-OutdoorAirIntake ;
#     ns1:hasQuantityKind <http://qudt.org/vocab/quantitykind/Temperature> .
#
# <urn:hpflex/shapes#QuantifiableObservableProperty_version_25> a ns1:QuantifiableObservableProperty,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_18>,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_25>,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_4> ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasAspect ns1:Role-Return ;
#     ns1:hasQuantityKind <http://qudt.org/vocab/quantitykind/Temperature> .
#
# <urn:hpflex/shapes#QuantifiableObservableProperty_version_26> a ns1:QuantifiableObservableProperty,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_17>,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_26>,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_5> ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasAspect ns1:Role-Supply ;
#     ns1:hasQuantityKind <http://qudt.org/vocab/quantitykind/Temperature> .
#
# <urn:hpflex/shapes#QuantifiableObservableProperty_version_27> a ns1:QuantifiableObservableProperty,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_16>,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_27>,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_6> ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasQuantityKind <http://qudt.org/vocab/quantitykind/Concentration> ;
#     ns1:ofConstituent rdfs:Resource ;
#     ns1:ofMedium rdfs:Resource .
#
# <urn:hpflex/shapes#QuantifiableObservableProperty_version_28> a ns1:QuantifiableObservableProperty,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_15>,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_28>,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_6> ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasQuantityKind <http://qudt.org/vocab/quantitykind/Concentration> ;
#     ns1:ofConstituent rdfs:Resource ;
#     ns1:ofMedium rdfs:Resource .
#
# <urn:hpflex/shapes#QuantifiableObservableProperty_version_29> a ns1:QuantifiableObservableProperty,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_14>,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_29>,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_7> ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasAspect ns1:Role-Discharge ;
#     ns1:hasQuantityKind <http://qudt.org/vocab/quantitykind/Temperature> .
#
# <urn:hpflex/shapes#QuantifiableObservableProperty_version_30> a ns1:QuantifiableObservableProperty,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_14>,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_30>,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_7> ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasAspect ns1:Role-Discharge ;
#     ns1:hasQuantityKind <http://qudt.org/vocab/quantitykind/Temperature> .
#
# <urn:hpflex/shapes#QuantifiableObservableProperty_version_31> a ns1:QuantifiableObservableProperty,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_13>,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_31>,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_8> ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasEnumerationKind ns1:EnumerationKind-Occupancy .
#
# <urn:hpflex/shapes#QuantifiableObservableProperty_version_32> a ns1:QuantifiableObservableProperty,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_12>,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_32>,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_8> ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasEnumerationKind ns1:EnumerationKind-Occupancy .
#
# <urn:hpflex/shapes#QuantifiableObservableProperty_version_33> a ns1:QuantifiableObservableProperty,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_11>,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_33>,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_9> ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasAspect ns1:Aspect-Setpoint ;
#     ns2:hasQuantityKind rdfs:Resource .
#
# <urn:hpflex/shapes#QuantifiableObservableProperty_version_34> a ns1:QuantifiableObservableProperty,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_10>,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_34>,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_9> ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasAspect ns1:Aspect-Setpoint ;
#     ns2:hasQuantityKind rdfs:Resource .
#
# <urn:hpflex/shapes#AirHandlingUnit_version_3> a ns1:AirHandlingUnit,
#         <urn:hpflex/shapes#AirHandlingUnit_version_1>,
#         <urn:hpflex/shapes#AirHandlingUnit_version_2>,
#         <urn:hpflex/shapes#AirHandlingUnit_version_3> ;
#     rdfs:label rdfs:Resource ;
#     ns1:cnx <urn:hpflex/shapes#OutletConnectionPoint_version_22>,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_24> ;
#     ns1:connectsTo <urn:hpflex/shapes#SingleDuctTerminal_version_5>,
#         <urn:hpflex/shapes#SingleDuctTerminal_version_6> ;
#     ns1:contains <urn:hpflex/shapes#Coil_version_8>,
#         <urn:hpflex/shapes#Coil_version_9>,
#         <urn:hpflex/shapes#Damper_version_8>,
#         <urn:hpflex/shapes#Fan_version_3> ;
#     ns1:hasProperty <urn:hpflex/shapes#QuantifiableObservableProperty_version_22>,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_23>,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_24>,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_25>,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_26> .
#
# <urn:hpflex/shapes#Connection_version_6> a ns1:Connection,
#         <urn:hpflex/shapes#Connection_version_1>,
#         <urn:hpflex/shapes#Connection_version_5>,
#         <urn:hpflex/shapes#Connection_version_6> ;
#     rdfs:label rdfs:Resource ;
#     ns1:cnx <urn:hpflex/shapes#InletConnectionPoint_version_12>,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_26> .
#
# <urn:hpflex/shapes#Connection_version_7> a ns1:Connection,
#         <urn:hpflex/shapes#Connection_version_1>,
#         <urn:hpflex/shapes#Connection_version_4>,
#         <urn:hpflex/shapes#Connection_version_7> ;
#     rdfs:label rdfs:Resource ;
#     ns1:cnx <urn:hpflex/shapes#InletConnectionPoint_version_14>,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_23> .
#
# <urn:hpflex/shapes#Connection_version_8> a ns1:Connection,
#         <urn:hpflex/shapes#Connection_version_1>,
#         <urn:hpflex/shapes#Connection_version_3>,
#         <urn:hpflex/shapes#Connection_version_8> ;
#     rdfs:label rdfs:Resource ;
#     ns1:cnx <urn:hpflex/shapes#InletConnectionPoint_version_13>,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_25> .
#
# <urn:hpflex/shapes#Fan_version_3> a ns1:Fan,
#         <urn:hpflex/shapes#Fan_version_1>,
#         <urn:hpflex/shapes#Fan_version_2>,
#         <urn:hpflex/shapes#Fan_version_3> ;
#     rdfs:label rdfs:Resource ;
#     ns1:cnx <urn:hpflex/shapes#OutletConnectionPoint_version_23> ;
#     ns1:connectsTo <urn:hpflex/shapes#Damper_version_8> ;
#     ns1:hasAspect ns1:Role-SupplyAir .
#
# <urn:hpflex/shapes#InletConnectionPoint_version_12> a ns1:InletConnectionPoint,
#         <urn:hpflex/shapes#InletConnectionPoint_version_12>,
#         <urn:hpflex/shapes#InletConnectionPoint_version_2>,
#         <urn:hpflex/shapes#InletConnectionPoint_version_9> ;
#     rdfs:label rdfs:Resource ;
#     ns1:cnx <urn:hpflex/shapes#Coil_version_8>,
#         <urn:hpflex/shapes#Connection_version_6> ;
#     ns1:hasMedium rdfs:Resource .
#
# <urn:hpflex/shapes#InletConnectionPoint_version_13> a ns1:InletConnectionPoint,
#         <urn:hpflex/shapes#InletConnectionPoint_version_13>,
#         <urn:hpflex/shapes#InletConnectionPoint_version_2>,
#         <urn:hpflex/shapes#InletConnectionPoint_version_8> ;
#     rdfs:label rdfs:Resource ;
#     ns1:cnx <urn:hpflex/shapes#Coil_version_9>,
#         <urn:hpflex/shapes#Connection_version_8> ;
#     ns1:hasMedium rdfs:Resource .
#
# <urn:hpflex/shapes#InletConnectionPoint_version_14> a ns1:InletConnectionPoint,
#         <urn:hpflex/shapes#InletConnectionPoint_version_14>,
#         <urn:hpflex/shapes#InletConnectionPoint_version_3>,
#         <urn:hpflex/shapes#InletConnectionPoint_version_7> ;
#     rdfs:label rdfs:Resource ;
#     ns1:cnx <urn:hpflex/shapes#Connection_version_7>,
#         <urn:hpflex/shapes#Damper_version_8> ;
#     ns1:hasMedium rdfs:Resource .
#
# <urn:hpflex/shapes#InletConnectionPoint_version_15> a ns1:InletConnectionPoint,
#         <urn:hpflex/shapes#InletConnectionPoint_version_15>,
#         <urn:hpflex/shapes#InletConnectionPoint_version_4>,
#         <urn:hpflex/shapes#InletConnectionPoint_version_6> ;
#     rdfs:label rdfs:Resource ;
#     ns1:cnx <urn:hpflex/shapes#Connection_version_9>,
#         <urn:hpflex/shapes#SingleDuctTerminal_version_5> ;
#     ns1:hasMedium rdfs:Resource .
#
# <urn:hpflex/shapes#InletConnectionPoint_version_16> a ns1:InletConnectionPoint,
#         <urn:hpflex/shapes#InletConnectionPoint_version_16>,
#         <urn:hpflex/shapes#InletConnectionPoint_version_4>,
#         <urn:hpflex/shapes#InletConnectionPoint_version_5> ;
#     rdfs:label rdfs:Resource ;
#     ns1:cnx <urn:hpflex/shapes#Connection_version_9>,
#         <urn:hpflex/shapes#SingleDuctTerminal_version_6> ;
#     ns1:hasMedium rdfs:Resource .
#
# <urn:hpflex/shapes#OutletConnectionPoint_version_22> a ns1:OutletConnectionPoint,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_13>,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_22>,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_4> ;
#     rdfs:label rdfs:Resource ;
#     ns1:cnx <urn:hpflex/shapes#AirHandlingUnit_version_3>,
#         <urn:hpflex/shapes#Connection_version_9> ;
#     ns1:hasMedium rdfs:Resource .
#
# <urn:hpflex/shapes#OutletConnectionPoint_version_23> a ns1:OutletConnectionPoint,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_12>,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_23>,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_5> ;
#     rdfs:label rdfs:Resource ;
#     ns1:cnx <urn:hpflex/shapes#Connection_version_7>,
#         <urn:hpflex/shapes#Fan_version_3> ;
#     ns1:hasMedium rdfs:Resource .
#
# <urn:hpflex/shapes#OutletConnectionPoint_version_24> a ns1:OutletConnectionPoint,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_11>,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_24>,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_6> ;
#     rdfs:label rdfs:Resource ;
#     ns1:cnx <urn:hpflex/shapes#AirHandlingUnit_version_3> ;
#     ns1:hasMedium rdfs:Resource .
#
# <urn:hpflex/shapes#OutletConnectionPoint_version_25> a ns1:OutletConnectionPoint,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_10>,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_25>,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_7> ;
#     rdfs:label rdfs:Resource ;
#     ns1:cnx <urn:hpflex/shapes#Coil_version_8>,
#         <urn:hpflex/shapes#Connection_version_8> ;
#     ns1:hasMedium rdfs:Resource .
#
# <urn:hpflex/shapes#OutletConnectionPoint_version_26> a ns1:OutletConnectionPoint,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_26>,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_8>,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_9> ;
#     rdfs:label rdfs:Resource ;
#     ns1:cnx <urn:hpflex/shapes#Connection_version_6>,
#         <urn:hpflex/shapes#Damper_version_8> ;
#     ns1:hasMedium rdfs:Resource .
#
# <urn:hpflex/shapes#Coil_version_7> a ns1:Coil,
#         <urn:hpflex/shapes#Coil_version_1>,
#         <urn:hpflex/shapes#Coil_version_6>,
#         <urn:hpflex/shapes#Coil_version_7> ;
#     rdfs:label rdfs:Resource ;
#     ns1:cnx <urn:hpflex/shapes#InletConnectionPoint_version_11>,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_21> ;
#     ns1:hasAspect ns1:Role-Heating ;
#     ns1:hasProperty <urn:hpflex/shapes#QuantifiableActuatableProperty_version_9> .
#
# <urn:hpflex/shapes#Connection_version_9> a ns1:Connection,
#         <urn:hpflex/shapes#Connection_version_1>,
#         <urn:hpflex/shapes#Connection_version_2>,
#         <urn:hpflex/shapes#Connection_version_9> ;
#     rdfs:label rdfs:Resource ;
#     ns1:cnx <urn:hpflex/shapes#InletConnectionPoint_version_15>,
#         <urn:hpflex/shapes#InletConnectionPoint_version_16>,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_22> .
#
# <urn:hpflex/shapes#SingleDuctTerminal_version_5> a ns1:SingleDuctTerminal,
#         <urn:hpflex/shapes#SingleDuctTerminal_version_1>,
#         <urn:hpflex/shapes#SingleDuctTerminal_version_4>,
#         <urn:hpflex/shapes#SingleDuctTerminal_version_5> ;
#     rdfs:label rdfs:Resource ;
#     ns1:cnx <urn:hpflex/shapes#InletConnectionPoint_version_15>,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_19> ;
#     ns1:contains <urn:hpflex/shapes#Damper_version_6> ;
#     ns1:hasProperty <urn:hpflex/shapes#QuantifiableObservableProperty_version_27>,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_31>,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_33> .
#
# <urn:hpflex/shapes#SingleDuctTerminal_version_6> a ns1:SingleDuctTerminal,
#         <urn:hpflex/shapes#SingleDuctTerminal_version_2>,
#         <urn:hpflex/shapes#SingleDuctTerminal_version_3>,
#         <urn:hpflex/shapes#SingleDuctTerminal_version_6> ;
#     rdfs:label rdfs:Resource ;
#     ns1:cnx <urn:hpflex/shapes#InletConnectionPoint_version_16>,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_20> ;
#     ns1:contains <urn:hpflex/shapes#Coil_version_7>,
#         <urn:hpflex/shapes#Damper_version_7> ;
#     ns1:hasProperty <urn:hpflex/shapes#QuantifiableObservableProperty_version_28>,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_32>,
#         <urn:hpflex/shapes#QuantifiableObservableProperty_version_34> .
#
# <urn:hpflex/shapes#Coil_version_8> a ns1:Coil,
#         <urn:hpflex/shapes#Coil_version_2>,
#         <urn:hpflex/shapes#Coil_version_5>,
#         <urn:hpflex/shapes#Coil_version_8> ;
#     rdfs:label rdfs:Resource ;
#     ns1:cnx <urn:hpflex/shapes#InletConnectionPoint_version_12>,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_25> ;
#     ns1:connectsTo <urn:hpflex/shapes#Coil_version_9> ;
#     ns1:hasAspect ns1:Role-Cooling .
#
# <urn:hpflex/shapes#Coil_version_9> a ns1:Coil,
#         <urn:hpflex/shapes#Coil_version_3>,
#         <urn:hpflex/shapes#Coil_version_4>,
#         <urn:hpflex/shapes#Coil_version_9> ;
#     rdfs:label rdfs:Resource ;
#     ns1:cnx <urn:hpflex/shapes#InletConnectionPoint_version_13>,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_18> ;
#     ns1:hasAspect ns1:Role-Heating .
#
# <urn:hpflex/shapes#Damper_version_8> a ns1:Damper,
#         <urn:hpflex/shapes#Damper_version_2>,
#         <urn:hpflex/shapes#Damper_version_3>,
#         <urn:hpflex/shapes#Damper_version_8> ;
#     rdfs:label rdfs:Resource ;
#     ns1:cnx <urn:hpflex/shapes#InletConnectionPoint_version_14>,
#         <urn:hpflex/shapes#OutletConnectionPoint_version_26> ;
#     ns1:connectsTo <urn:hpflex/shapes#Coil_version_8> ;
#     ns1:hasProperty <urn:hpflex/shapes#QuantifiableActuatableProperty_version_6> .

# %%
len(cm[2])
# Out:
# 47

# %%
i = 5
list(cm[0].values())[i][0].split('#')[-1]
# Out:
# 'QuantifiableObservableProperty'

# %%
# sorting through to look pritier
for s,p,o in cg:
    if (p == A) & (str(HPFS) in str(o)):
        cg.remove((s,p,o))
    if p == RDFS.label:
        cg.remove((s,p,o))
bind_prefixes(cg)
cg.serialize('algo5-s223.ttl')
# Out:
# <Graph identifier=N3772b9d032144b34b982254f9793551e (<class 'rdflib.graph.Graph'>)>

# %%
mortar_b1 = Graph(store = 'Oxigraph')
mortar_b1.parse("mortar/buildings/bldg1.ttl", format="turtle")
cg, dg, cm = run_algo(mortar_b1, 5)
# Out:
# 100%|██████████| 692/692 [00:00<00:00, 4937.29it/s]
# 100%|██████████| 986/986 [00:00<00:00, 4269.60it/s]
# 100%|██████████| 1280/1280 [00:00<00:00, 3474.52it/s]
# 100%|██████████| 1574/1574 [00:00<00:00, 3348.84it/s]
# 100%|██████████| 1868/1868 [00:00<00:00, 3471.02it/s]
# Algorithm stopped, since no further distinguishing classes found. Process took  4 iterations
# Printing Last Set Difference
# [{'common': [rdflib.term.URIRef('http://buildsys.org/ontologies/bldg1#RM115_room'),
#              rdflib.term.URIRef('http://buildsys.org/ontologies/bldg1#RM107A_room'),
#              rdflib.term.URIRef('http://buildsys.org/ontologies/bldg1#RM120_room'),
#              rdflib.term.URIRef('http://buildsys.org/ontologies/bldg1#RM107B_room')],
#   'intersection_size': 4,
#   'jaccard_similarity': 0.5,
#   'list1_index': 3,
#   'list2_index': 42,
#   'only_in_list1': [],
#   'only_in_list2': [rdflib.term.URIRef('http://buildsys.org/ontologies/bldg1#RM103_room'),
#                     rdflib.term.URIRef('http://buildsys.org/ontologies/bldg1#RM100_room'),
#                     rdflib.term.URIRef('http://buildsys.org/ontologies/bldg1#RM112_room'),
#                     rdflib.term.URIRef('http://buildsys.org/ontologies/bldg1#RM110_room')],
#   'size_list1': 4,
#   'size_list2': 8},
#  {'common': [rdflib.term.URIRef('http://buildsys.org/ontologies/bldg1#RM103_room'),
#              rdflib.term.URIRef('http://buildsys.org/ontologies/bldg1#RM100_room'),
#              rdflib.term.URIRef('http://buildsys.org/ontologies/bldg1#RM112_room'),
#              rdflib.term.URIRef('http://buildsys.org/ontologies/bldg1#RM110_room')],
#   'intersection_size': 4,
#   'jaccard_similarity': 0.5,
#   'list1_index': 4,
#   'list2_index': 42,
#   'only_in_list1': [],
#   'only_in_list2': [rdflib.term.URIRef('http://buildsys.org/ontologies/bldg1#RM107B_room'),
#                     rdflib.term.URIRef('http://buildsys.org/ontologies/bldg1#RM107A_room'),
#                     rdflib.term.URIRef('http://buildsys.org/ontologies/bldg1#RM120_room'),
#                     rdflib.term.URIRef('http://buildsys.org/ontologies/bldg1#RM115_room')],
#   'size_list1': 4,
#   'size_list2': 8},
#  {'common': [rdflib.term.URIRef('http://buildsys.org/ontologies/bldg1#bldg1.ZONE.AHU02.RM110.Zone_Air_Damper_Command'),
#              rdflib.term.URIRef('http://buildsys.org/ontologies/bldg1#bldg1.ZONE.AHU02.RM103.Zone_Air_Damper_Command'),
#              rdflib.term.URIRef('http://buildsys.org/ontologies/bldg1#bldg1.ZONE.AHU02.RM100.Zone_Air_Damper_Command'),
#              rdflib.term.URIRef('http://buildsys.org/ontologies/bldg1#bldg1.ZONE.AHU02.RM112.Zone_Air_Damper_Command')],
#   'intersection_size': 4,
#   'jaccard_similarity': 0.5,
#   'list1_index': 17,
#   'list2_index': 29,
#   'only_in_list1': [],
#   'only_in_list2': [rdflib.term.URIRef('http://buildsys.org/ontologies/bldg1#bldg1.ZONE.AHU01.RM120.Zone_Air_Damper_Command'),
#                     rdflib.term.URIRef('http://buildsys.org/ontologies/bldg1#bldg1.ZONE.AHU01.RM107A.Zone_Air_Damper_Command'),
#                     rdflib.term.URIRef('http://buildsys.org/ontologies/bldg1#bldg1.ZONE.AHU01.RM107B.Zone_Air_Damper_Command'),
#                     rdflib.term.URIRef('http://buildsys.org/ontologies/bldg1#bldg1.ZONE.AHU01.RM115.Zone_Air_Damper_Command')],
#   'size_list1': 4,
#   'size_list2': 8},
#  {'common': [rdflib.term.URIRef('http://buildsys.org/ontologies/bldg1#bldg1.ZONE.AHU01.RM120.Zone_Air_Damper_Command'),
#              rdflib.term.URIRef('http://buildsys.org/ontologies/bldg1#bldg1.ZONE.AHU01.RM107A.Zone_Air_Damper_Command'),
#              rdflib.term.URIRef('http://buildsys.org/ontologies/bldg1#bldg1.ZONE.AHU01.RM107B.Zone_Air_Damper_Command'),
#              rdflib.term.URIRef('http://buildsys.org/ontologies/bldg1#bldg1.ZONE.AHU01.RM115.Zone_Air_Damper_Command')],
#   'intersection_size': 4,
#   'jaccard_similarity': 0.5,
#   'list1_index': 18,
#   'list2_index': 29,
#   'only_in_list1': [],
#   'only_in_list2': [rdflib.term.URIRef('http://buildsys.org/ontologies/bldg1#bldg1.ZONE.AHU02.RM110.Zone_Air_Damper_Command'),
#                     rdflib.term.URIRef('http://buildsys.org/ontologies/bldg1#bldg1.ZONE.AHU02.RM103.Zone_Air_Damper_Command'),
#                     rdflib.term.URIRef('http://buildsys.org/ontologies/bldg1#bldg1.ZONE.AHU02.RM100.Zone_Air_Damper_Command'),
#                     rdflib.term.URIRef('http://buildsys.org/ontologies/bldg1#bldg1.ZONE.AHU02.RM112.Zone_Air_Damper_Command')],
#   'size_list1': 4,
#   'size_list2': 8}]

# %%
# remove extra stuff added to cg
for s,p,o in cg:
    if (p == A) & (str(HPFS) in str(o)):
        cg.remove((s,p,o))
print("mortar b1 shrunk to ", len(cg)/len(mortar_b1)* 100, "% of its original size ")
# Out:
# mortar b1 shrunk to  23.265895953757227 % of its original size

# %%
cg.print()
# Out:
# @prefix brick: <https://brickschema.org/schema/Brick#> .
# @prefix ns1: <https://brickschema.org/schema/Brick/ref#> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# <urn:hpflex/shapes#Air_Handler_Unit_version_7> a brick:Air_Handler_Unit ;
#     brick:feeds <urn:hpflex/shapes#VAV_version_7> ;
#     brick:hasPoint <urn:hpflex/shapes#Cooling_Command_version_6>,
#         <urn:hpflex/shapes#Mixed_Air_Temperature_Sensor_version_6>,
#         <urn:hpflex/shapes#Outside_Air_Temperature_Sensor_version_7>,
#         <urn:hpflex/shapes#Return_Air_Temperature_Sensor_version_6>,
#         <urn:hpflex/shapes#Supply_Air_Static_Pressure_Sensor_version_6>,
#         <urn:hpflex/shapes#Supply_Air_Temperature_Sensor_version_12> ;
#     brick:isFedBy <urn:hpflex/shapes#Chiller_version_4> .
#
# <urn:hpflex/shapes#Air_Handler_Unit_version_8> a brick:Air_Handler_Unit ;
#     brick:feeds <urn:hpflex/shapes#VAV_version_6> ;
#     brick:hasPoint <urn:hpflex/shapes#Cooling_Command_version_7>,
#         <urn:hpflex/shapes#Mixed_Air_Temperature_Sensor_version_7>,
#         <urn:hpflex/shapes#Outside_Air_Temperature_Sensor_version_8>,
#         <urn:hpflex/shapes#Return_Air_Temperature_Sensor_version_7>,
#         <urn:hpflex/shapes#Supply_Air_Static_Pressure_Sensor_version_7>,
#         <urn:hpflex/shapes#Supply_Air_Temperature_Sensor_version_13>,
#         <urn:hpflex/shapes#Supply_Air_Temperature_Setpoint_version_4> ;
#     brick:isFedBy <urn:hpflex/shapes#Chiller_version_4> .
#
# <urn:hpflex/shapes#Building_version_4> a brick:Building ;
#     brick:area <urn:hpflex/shapes#Resource_version_4> .
#
# <urn:hpflex/shapes#Damper_version_5> a brick:Damper ;
#     brick:hasPoint <urn:hpflex/shapes#Damper_Position_Setpoint_version_5> ;
#     brick:isPartOf <urn:hpflex/shapes#VAV_version_6> .
#
# <urn:hpflex/shapes#Damper_version_6> a brick:Damper ;
#     brick:hasPoint <urn:hpflex/shapes#Damper_Position_Setpoint_version_4> ;
#     brick:isPartOf <urn:hpflex/shapes#VAV_version_7> .
#
# <urn:hpflex/shapes#Floor_version_4> a brick:Floor ;
#     brick:hasPart <urn:hpflex/shapes#Room_version_4>,
#         <urn:hpflex/shapes#Room_version_5> .
#
# <urn:hpflex/shapes#Ontology_version_4> a owl:Ontology ;
#     rdfs:label rdfs:Resource ;
#     owl:imports rdfs:Resource .
#
# <urn:hpflex/shapes#Air_Flow_Sensor_version_5> a brick:Air_Flow_Sensor ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasExternalReference <urn:hpflex/shapes#Resource_version_4> .
#
# <urn:hpflex/shapes#Air_Flow_Sensor_version_6> a brick:Air_Flow_Sensor ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasExternalReference <urn:hpflex/shapes#Resource_version_4> .
#
# <urn:hpflex/shapes#Chilled_Water_Return_Temperature_Sensor_version_4> a brick:Chilled_Water_Return_Temperature_Sensor ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasExternalReference <urn:hpflex/shapes#Resource_version_4> .
#
# <urn:hpflex/shapes#Chilled_Water_Supply_Temperature_Sensor_version_4> a brick:Chilled_Water_Supply_Temperature_Sensor ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasExternalReference <urn:hpflex/shapes#Resource_version_4> .
#
# <urn:hpflex/shapes#Command_version_5> a brick:Command ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasExternalReference <urn:hpflex/shapes#Resource_version_4> .
#
# <urn:hpflex/shapes#Command_version_6> a brick:Command ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasExternalReference <urn:hpflex/shapes#Resource_version_4> .
#
# <urn:hpflex/shapes#Cooling_Command_version_6> a brick:Cooling_Command,
#         brick:Valve_Command ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasExternalReference <urn:hpflex/shapes#Resource_version_4> .
#
# <urn:hpflex/shapes#Cooling_Command_version_7> a brick:Cooling_Command,
#         brick:Valve_Command ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasExternalReference <urn:hpflex/shapes#Resource_version_4> .
#
# <urn:hpflex/shapes#Damper_Position_Command_version_4> a brick:Damper_Position_Command ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasExternalReference <urn:hpflex/shapes#Resource_version_4> .
#
# <urn:hpflex/shapes#Damper_Position_Setpoint_version_4> a brick:Damper_Position_Setpoint ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasExternalReference <urn:hpflex/shapes#Resource_version_4> .
#
# <urn:hpflex/shapes#Damper_Position_Setpoint_version_5> a brick:Damper_Position_Setpoint ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasExternalReference <urn:hpflex/shapes#Resource_version_4> .
#
# <urn:hpflex/shapes#HVAC_Zone_version_5> a brick:HVAC_Zone ;
#     brick:hasPart <urn:hpflex/shapes#Room_version_4> .
#
# <urn:hpflex/shapes#HVAC_Zone_version_6> a brick:HVAC_Zone ;
#     brick:hasPart <urn:hpflex/shapes#Room_version_5> .
#
# <urn:hpflex/shapes#Heating_Command_version_5> a brick:Heating_Command ;
#     rdfs:label rdfs:Resource .
#
# <urn:hpflex/shapes#Heating_Command_version_6> a brick:Heating_Command ;
#     rdfs:label rdfs:Resource .
#
# <urn:hpflex/shapes#Mixed_Air_Temperature_Sensor_version_6> a brick:Mixed_Air_Temperature_Sensor ;
#     rdfs:label rdfs:Resource .
#
# <urn:hpflex/shapes#Mixed_Air_Temperature_Sensor_version_7> a brick:Mixed_Air_Temperature_Sensor ;
#     rdfs:label rdfs:Resource .
#
# <urn:hpflex/shapes#Outside_Air_Temperature_Sensor_version_7> a brick:Outside_Air_Temperature_Sensor ;
#     rdfs:label rdfs:Resource .
#
# <urn:hpflex/shapes#Outside_Air_Temperature_Sensor_version_8> a brick:Outside_Air_Temperature_Sensor ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasExternalReference <urn:hpflex/shapes#Resource_version_4> .
#
# <urn:hpflex/shapes#Return_Air_Temperature_Sensor_version_6> a brick:Return_Air_Temperature_Sensor ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasExternalReference <urn:hpflex/shapes#Resource_version_4> .
#
# <urn:hpflex/shapes#Return_Air_Temperature_Sensor_version_7> a brick:Return_Air_Temperature_Sensor ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasExternalReference <urn:hpflex/shapes#Resource_version_4> .
#
# <urn:hpflex/shapes#Start_Stop_Command_version_4> a brick:Start_Stop_Command ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasExternalReference <urn:hpflex/shapes#Resource_version_4> .
#
# <urn:hpflex/shapes#Supply_Air_Flow_Sensor_version_5> a brick:Supply_Air_Flow_Sensor ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasExternalReference <urn:hpflex/shapes#Resource_version_4> .
#
# <urn:hpflex/shapes#Supply_Air_Flow_Sensor_version_6> a brick:Supply_Air_Flow_Sensor ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasExternalReference <urn:hpflex/shapes#Resource_version_4> .
#
# <urn:hpflex/shapes#Supply_Air_Static_Pressure_Sensor_version_6> a brick:Supply_Air_Static_Pressure_Sensor ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasExternalReference <urn:hpflex/shapes#Resource_version_4> .
#
# <urn:hpflex/shapes#Supply_Air_Static_Pressure_Sensor_version_7> a brick:Supply_Air_Static_Pressure_Sensor ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasExternalReference <urn:hpflex/shapes#Resource_version_4> .
#
# <urn:hpflex/shapes#Supply_Air_Temperature_Sensor_version_10> a brick:Supply_Air_Temperature_Sensor ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasExternalReference <urn:hpflex/shapes#Resource_version_4> .
#
# <urn:hpflex/shapes#Supply_Air_Temperature_Sensor_version_11> a brick:Supply_Air_Temperature_Sensor ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasExternalReference <urn:hpflex/shapes#Resource_version_4> .
#
# <urn:hpflex/shapes#Supply_Air_Temperature_Sensor_version_12> a brick:Supply_Air_Temperature_Sensor ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasExternalReference <urn:hpflex/shapes#Resource_version_4> .
#
# <urn:hpflex/shapes#Supply_Air_Temperature_Sensor_version_13> a brick:Supply_Air_Temperature_Sensor ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasExternalReference <urn:hpflex/shapes#Resource_version_4> .
#
# <urn:hpflex/shapes#Supply_Air_Temperature_Setpoint_version_4> a brick:Supply_Air_Temperature_Setpoint ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasExternalReference <urn:hpflex/shapes#Resource_version_4> .
#
# <urn:hpflex/shapes#Zone_Air_Temperature_Sensor_version_5> a brick:Zone_Air_Temperature_Sensor ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasExternalReference <urn:hpflex/shapes#Resource_version_4> .
#
# <urn:hpflex/shapes#Zone_Air_Temperature_Sensor_version_6> a brick:Zone_Air_Temperature_Sensor ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasExternalReference <urn:hpflex/shapes#Resource_version_4> .
#
# <urn:hpflex/shapes#Zone_Air_Temperature_Setpoint_version_5> a brick:Zone_Air_Temperature_Setpoint ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasExternalReference <urn:hpflex/shapes#Resource_version_4> .
#
# <urn:hpflex/shapes#Zone_Air_Temperature_Setpoint_version_6> a brick:Zone_Air_Temperature_Setpoint ;
#     rdfs:label rdfs:Resource ;
#     ns1:hasExternalReference <urn:hpflex/shapes#Resource_version_4> .
#
# <urn:hpflex/shapes#Chiller_version_4> a brick:Chiller ;
#     brick:hasPoint <urn:hpflex/shapes#Chilled_Water_Return_Temperature_Sensor_version_4>,
#         <urn:hpflex/shapes#Chilled_Water_Supply_Temperature_Sensor_version_4>,
#         <urn:hpflex/shapes#Damper_Position_Command_version_4>,
#         <urn:hpflex/shapes#Start_Stop_Command_version_4> .
#
# <urn:hpflex/shapes#Room_version_4> a brick:Room .
#
# <urn:hpflex/shapes#Room_version_5> a brick:Room .
#
# <urn:hpflex/shapes#VAV_version_6> a brick:VAV ;
#     brick:feeds <urn:hpflex/shapes#HVAC_Zone_version_5> ;
#     brick:hasPoint <urn:hpflex/shapes#Air_Flow_Sensor_version_6>,
#         <urn:hpflex/shapes#Command_version_6>,
#         <urn:hpflex/shapes#Heating_Command_version_6>,
#         <urn:hpflex/shapes#Supply_Air_Flow_Sensor_version_6>,
#         <urn:hpflex/shapes#Supply_Air_Temperature_Sensor_version_11>,
#         <urn:hpflex/shapes#Zone_Air_Temperature_Sensor_version_6>,
#         <urn:hpflex/shapes#Zone_Air_Temperature_Setpoint_version_6> .
#
# <urn:hpflex/shapes#VAV_version_7> a brick:VAV ;
#     brick:feeds <urn:hpflex/shapes#HVAC_Zone_version_6> ;
#     brick:hasPoint <urn:hpflex/shapes#Air_Flow_Sensor_version_5>,
#         <urn:hpflex/shapes#Command_version_5>,
#         <urn:hpflex/shapes#Heating_Command_version_5>,
#         <urn:hpflex/shapes#Supply_Air_Flow_Sensor_version_5>,
#         <urn:hpflex/shapes#Supply_Air_Temperature_Sensor_version_10>,
#         <urn:hpflex/shapes#Zone_Air_Temperature_Sensor_version_5>,
#         <urn:hpflex/shapes#Zone_Air_Temperature_Setpoint_version_5> .
#
# <urn:hpflex/shapes#Resource_version_4> brick:hasUnits rdfs:Resource ;
#     brick:value rdfs:Resource ;
#     ns1:hasTimeseriesId rdfs:Resource .

# %%
print("mortar b1 shrunk to ", len(cg)/len(mortar_b1)* 100, "% of its original size ")
# Out:
# mortar b1 shrunk to  23.265895953757227 % of its original size

# %% [markdown]
# # old code

# %%
# # pip install transformers
# from transformers import AutoModelForCausalLM, AutoTokenizer
# checkpoint = "HuggingFaceTB/SmolLM3-3B"

# device = "cuda" 
# tokenizer = AutoTokenizer.from_pretrained(checkpoint)
# # for multiple GPUs install accelerate and do `model = AutoModelForCausalLM.from_pretrained(checkpoint, device_map="auto")`
# model = AutoModelForCausalLM.from_pretrained(checkpoint)

# %%
# i=5
# cls_name = list(cm[0].values())[i][0].split('#')[-1]
# cls_graph = list(cm[0].values())[i][1].serialize(format = 'ttl')
# messages = [{"role":"system",
#              "content": "Please provide a brief reply with the new brick class within the tags <brick-class></brick-class> so that I can retrieve it."},
#             {"role": "user", 
#              "content": f"""If it is possible to further specify the class name based on the RDF graph of nodes surrounding it, provide a more specific brick ontology class name.
#             The current class name is {cls_name} and the RDF graph of surrounding nodes is {cls_graph}"""}]
# input_text=tokenizer.apply_chat_template(messages, tokenize=False)
# # print(input_text)
# inputs = tokenizer.apply_chat_template(
#     messages,
#     # enable_thinking=True,
#     tokenize=True,
#     return_tensors="pt",
# )

# outputs = model.generate(inputs, max_new_tokens=100)
# print(tokenizer.decode(outputs[0], skip_special_tokens=True))

# %%
output_text = tokenizer.decode(outputs[0])
output_text.split('\n')[-1].split('<|im_end|>')[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 output_text = tokenizer.decode(outputs[0])
#       2 output_text.split('\n')[-1].split('<|im_end|>')[0]
#
# NameError: name 'tokenizer' is not defined

# %%
assign_new_classes(data_graph)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 assign_new_classes(data_graph)
#
# TypeError: assign_new_classes() missing 2 required positional arguments: 'equivalent_subjects' and 'subject_classes'

# %%
distinct_class_subgraphs[0]
# Out:
# <Graph identifier=N5d7d30764f494f0cb7110a871aa59d36 (<class 'rdflib.graph.Graph'>)>

# %%
distinct_class_subgraphs, seen_subjects, equivalent_subjects, subject_classes = get_class_isomorphisms(data_graph)
pprint(equivalent_subjects)

distinct_class_subgraphs, seen_subjects, equivalent_subjects, subject_classes = get_class_isomorphisms(s223_data_graph)
pprint(equivalent_subjects)
# Out:
# 100%|██████████| 3429/3429 [00:01<00:00, 3152.39it/s]
# [[rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_3_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_3_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_3_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_3_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_3_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_3_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_3_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_3_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_3_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_3_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_3_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_3_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_3_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_3_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_3_0'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_2_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_2_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_2_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_2_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_2_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_2_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_2_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_2_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_2_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_2_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_2_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_2_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_2_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_2_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_2_0'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_1_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_1_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_1_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_1_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_1_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_1_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_1_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_1_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_1_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_1_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_1_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_1_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_1_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_1_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_1_0'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_0_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_0_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_0_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_0_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_0_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_0_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_0_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_0_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_0_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_0_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_0_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_0_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_0_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_0_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc_0_0')],
#  [rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_3_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_3_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_3_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_3_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_3_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_3_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_3_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_3_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_3_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_3_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_3_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_3_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_3_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_3_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_3_0'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_2_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_2_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_2_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_2_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_2_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_2_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_2_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_2_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_2_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_2_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_2_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_2_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_2_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_2_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_2_0'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_1_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_1_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_1_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_1_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_1_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_1_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_1_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_1_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_1_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_1_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_1_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_1_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_1_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_1_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_1_0'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_0_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_0_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_0_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_0_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_0_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_0_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_0_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_0_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_0_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_0_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_0_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_0_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_0_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_0_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_rhc-cmd_0_0')],
#  [rdflib.term.URIRef('urn:example#vav-with-reheat_name_3_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_3_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_3_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_3_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_3_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_3_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_3_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_3_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_3_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_3_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_3_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_3_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_3_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_3_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_3_0'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_2_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_2_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_2_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_2_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_2_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_2_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_2_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_2_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_2_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_2_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_2_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_2_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_2_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_2_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_2_0'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_1_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_1_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_1_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_1_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_1_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_1_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_1_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_1_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_1_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_1_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_1_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_1_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_1_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_1_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_1_0'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_0_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_0_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_0_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_0_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_0_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_0_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_0_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_0_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_0_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_0_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_0_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_0_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_0_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_0_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name_0_0')],
#  [rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_3_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_3_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_3_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_3_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_3_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_3_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_3_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_3_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_3_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_3_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_3_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_3_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_3_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_3_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_3_0'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_2_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_2_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_2_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_2_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_2_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_2_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_2_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_2_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_2_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_2_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_2_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_2_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_2_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_2_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_2_0'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_1_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_1_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_1_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_1_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_1_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_1_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_1_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_1_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_1_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_1_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_1_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_1_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_1_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_1_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_1_0'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_0_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_0_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_0_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_0_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_0_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_0_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_0_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_0_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_0_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_0_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_0_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_0_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_0_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_0_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-ztemp_0_0'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_3_9'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_3_8'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_3_7'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_3_6'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_3_5'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_3_4'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_3_3'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_3_2'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_3_14'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_3_13'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_3_12'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_3_11'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_3_10'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_3_1'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_3_0'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_2_9'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_2_8'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_2_7'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_2_6'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_2_5'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_2_4'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_2_3'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_2_2'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_2_14'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_2_13'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_2_12'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_2_11'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_2_10'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_2_1'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_2_0'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_1_9'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_1_8'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_1_7'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_1_6'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_1_5'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_1_4'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_1_3'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_1_2'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_1_14'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_1_13'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_1_12'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_1_11'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_1_10'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_1_1'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_1_0'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_0_9'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_0_8'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_0_7'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_0_6'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_0_5'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_0_4'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_0_3'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_0_2'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_0_14'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_0_13'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_0_12'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_0_11'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_0_10'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_0_1'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_ztemp_0_0')],
#  [rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_3_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_3_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_3_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_3_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_3_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_3_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_3_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_3_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_3_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_3_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_3_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_3_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_3_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_3_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_3_0'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_2_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_2_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_2_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_2_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_2_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_2_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_2_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_2_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_2_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_2_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_2_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_2_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_2_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_2_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_2_0'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_1_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_1_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_1_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_1_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_1_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_1_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_1_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_1_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_1_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_1_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_1_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_1_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_1_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_1_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_1_0'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_0_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_0_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_0_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_0_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_0_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_0_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_0_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_0_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_0_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_0_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_0_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_0_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_0_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_0_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_0_0'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_3_9'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_3_8'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_3_7'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_3_6'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_3_5'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_3_4'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_3_3'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_3_2'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_3_14'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_3_13'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_3_12'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_3_11'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_3_10'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_3_1'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_3_0'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_2_9'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_2_8'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_2_7'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_2_6'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_2_5'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_2_4'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_2_3'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_2_2'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_2_14'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_2_13'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_2_12'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_2_11'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_2_10'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_2_1'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_2_0'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_1_9'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_1_8'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_1_7'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_1_6'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_1_5'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_1_4'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_1_3'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_1_2'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_1_14'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_1_13'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_1_12'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_1_11'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_1_10'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_1_1'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_1_0'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_0_9'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_0_8'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_0_7'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_0_6'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_0_5'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_0_4'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_0_3'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_0_2'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_0_14'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_0_13'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_0_12'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_0_11'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_0_10'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_0_1'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_0_0')],
#  [rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_3_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_3_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_3_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_3_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_3_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_3_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_3_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_3_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_3_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_3_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_3_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_3_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_3_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_3_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_3_0'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_2_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_2_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_2_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_2_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_2_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_2_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_2_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_2_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_2_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_2_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_2_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_2_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_2_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_2_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_2_0'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_1_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_1_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_1_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_1_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_1_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_1_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_1_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_1_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_1_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_1_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_1_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_1_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_1_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_1_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_1_0'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_0_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_0_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_0_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_0_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_0_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_0_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_0_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_0_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_0_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_0_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_0_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_0_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_0_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_0_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-occ_0_0'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_3_9'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_3_8'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_3_7'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_3_6'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_3_5'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_3_4'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_3_3'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_3_2'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_3_14'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_3_13'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_3_12'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_3_11'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_3_10'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_3_1'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_3_0'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_2_9'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_2_8'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_2_7'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_2_6'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_2_5'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_2_4'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_2_3'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_2_2'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_2_14'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_2_13'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_2_12'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_2_11'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_2_10'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_2_1'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_2_0'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_1_9'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_1_8'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_1_7'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_1_6'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_1_5'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_1_4'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_1_3'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_1_2'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_1_14'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_1_13'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_1_12'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_1_11'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_1_10'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_1_1'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_1_0'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_0_9'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_0_8'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_0_7'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_0_6'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_0_5'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_0_4'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_0_3'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_0_2'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_0_14'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_0_13'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_0_12'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_0_11'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_0_10'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_0_1'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_occ_0_0')],
#  [rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_3_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_3_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_3_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_3_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_3_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_3_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_3_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_3_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_3_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_3_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_3_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_3_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_3_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_3_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_3_0'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_2_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_2_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_2_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_2_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_2_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_2_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_2_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_2_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_2_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_2_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_2_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_2_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_2_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_2_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_2_0'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_1_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_1_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_1_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_1_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_1_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_1_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_1_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_1_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_1_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_1_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_1_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_1_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_1_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_1_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_1_0'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_0_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_0_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_0_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_0_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_0_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_0_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_0_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_0_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_0_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_0_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_0_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_0_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_0_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_0_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp_0_0'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_3_9'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_3_8'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_3_7'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_3_6'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_3_5'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_3_4'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_3_3'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_3_2'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_3_14'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_3_13'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_3_12'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_3_11'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_3_10'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_3_1'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_3_0'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_2_9'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_2_8'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_2_7'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_2_6'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_2_5'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_2_4'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_2_3'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_2_2'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_2_14'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_2_13'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_2_12'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_2_11'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_2_10'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_2_1'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_2_0'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_1_9'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_1_8'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_1_7'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_1_6'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_1_5'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_1_4'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_1_3'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_1_2'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_1_14'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_1_13'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_1_12'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_1_11'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_1_10'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_1_1'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_1_0'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_0_9'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_0_8'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_0_7'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_0_6'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_0_5'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_0_4'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_0_3'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_0_2'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_0_14'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_0_13'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_0_12'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_0_11'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_0_10'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_0_1'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_0_0')],
#  [rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_3_0'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_2_0'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_1_0'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-dmp-dmppos_0_0'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_9'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_8'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_7'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_6'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_5'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_4'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_3'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_2'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_14'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_13'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_12'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_11'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp-dmppos_3_10'),
# ...
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_3_0'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_2_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_2_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_2_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_2_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_2_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_2_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_2_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_2_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_2_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_2_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_2_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_2_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_2_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_2_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_2_0'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_1_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_1_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_1_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_1_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_1_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_1_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_1_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_1_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_1_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_1_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_1_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_1_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_1_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_1_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_1_0'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_0_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_0_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_0_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_0_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_0_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_0_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_0_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_0_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_0_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_0_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_0_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_0_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_0_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_0_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_dmp_0_0'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_3_9'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_3_8'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_3_7'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_3_6'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_3_5'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_3_4'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_3_3'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_3_2'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_3_14'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_3_13'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_3_12'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_3_11'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_3_10'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_3_1'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_3_0'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_2_9'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_2_8'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_2_7'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_2_6'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_2_5'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_2_4'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_2_3'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_2_2'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_2_14'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_2_13'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_2_12'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_2_11'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_2_10'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_2_1'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_2_0'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_1_9'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_1_8'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_1_7'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_1_6'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_1_5'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_1_4'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_1_3'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_1_2'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_1_14'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_1_13'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_1_12'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_1_11'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_1_10'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_1_1'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_1_0'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_0_9'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_0_8'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_0_7'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_0_6'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_0_5'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_0_4'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_0_3'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_0_2'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_0_14'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_0_13'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_0_12'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_0_11'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_0_10'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_0_1'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_dmp_0_0')],
#  [rdflib.term.URIRef('urn:example#target_cp_a911e63a'),
#   rdflib.term.URIRef('urn:example#target_cp_7ff9596c'),
#   rdflib.term.URIRef('urn:example#target_cp_2e9b002e'),
#   rdflib.term.URIRef('urn:example#target_cp_15bb3ad0')],
#  [rdflib.term.URIRef('urn:example#multiple-zone-ahu_sa_temp_3'),
#   rdflib.term.URIRef('urn:example#multiple-zone-ahu_sa_temp_2'),
#   rdflib.term.URIRef('urn:example#multiple-zone-ahu_sa_temp_1'),
#   rdflib.term.URIRef('urn:example#multiple-zone-ahu_sa_temp_0'),
#   rdflib.term.URIRef('urn:example#multiple-zone-ahu_ra_temp_3'),
#   rdflib.term.URIRef('urn:example#multiple-zone-ahu_ra_temp_2'),
#   rdflib.term.URIRef('urn:example#multiple-zone-ahu_ra_temp_1'),
#   rdflib.term.URIRef('urn:example#multiple-zone-ahu_ra_temp_0'),
#   rdflib.term.URIRef('urn:example#multiple-zone-ahu_oa_temp_3'),
#   rdflib.term.URIRef('urn:example#multiple-zone-ahu_oa_temp_2'),
#   rdflib.term.URIRef('urn:example#multiple-zone-ahu_oa_temp_1'),
#   rdflib.term.URIRef('urn:example#multiple-zone-ahu_oa_temp_0'),
#   rdflib.term.URIRef('urn:example#multiple-zone-ahu_filter_pd_3'),
#   rdflib.term.URIRef('urn:example#multiple-zone-ahu_filter_pd_2'),
#   rdflib.term.URIRef('urn:example#multiple-zone-ahu_filter_pd_1'),
#   rdflib.term.URIRef('urn:example#multiple-zone-ahu_filter_pd_0')],
#  [rdflib.term.URIRef('urn:example#multiple-zone-ahu_ma_temp_3'),
#   rdflib.term.URIRef('urn:example#multiple-zone-ahu_ma_temp_2'),
#   rdflib.term.URIRef('urn:example#multiple-zone-ahu_ma_temp_1'),
#   rdflib.term.URIRef('urn:example#multiple-zone-ahu_ma_temp_0')],
#  [rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_3_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_3_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_3_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_3_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_3_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_3_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_3_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_3_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_3_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_3_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_3_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_3_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_3_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_3_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_3_0'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_2_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_2_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_2_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_2_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_2_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_2_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_2_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_2_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_2_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_2_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_2_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_2_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_2_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_2_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_2_0'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_1_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_1_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_1_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_1_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_1_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_1_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_1_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_1_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_1_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_1_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_1_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_1_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_1_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_1_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_1_0'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_0_9'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_0_8'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_0_7'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_0_6'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_0_5'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_0_4'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_0_3'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_0_2'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_0_14'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_0_13'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_0_12'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_0_11'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_0_10'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_0_1'),
#   rdflib.term.URIRef('urn:example#vav-with-reheat_name-zone_0_0'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_3_9'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_3_8'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_3_7'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_3_6'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_3_5'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_3_4'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_3_3'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_3_2'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_3_14'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_3_13'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_3_12'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_3_11'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_3_10'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_3_1'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_3_0'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_2_9'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_2_8'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_2_7'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_2_6'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_2_5'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_2_4'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_2_3'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_2_2'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_2_14'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_2_13'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_2_12'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_2_11'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_2_10'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_2_1'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_2_0'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_1_9'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_1_8'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_1_7'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_1_6'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_1_5'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_1_4'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_1_3'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_1_2'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_1_14'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_1_13'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_1_12'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_1_11'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_1_10'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_1_1'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_1_0'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_0_9'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_0_8'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_0_7'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_0_6'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_0_5'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_0_4'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_0_3'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_0_2'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_0_14'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_0_13'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_0_12'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_0_11'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_0_10'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_0_1'),
#   rdflib.term.URIRef('urn:example#vav-cooling-only_zone_0_0')],
#  [rdflib.term.URIRef('urn:example#')]]
